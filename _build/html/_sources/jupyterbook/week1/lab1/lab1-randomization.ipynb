# %% [markdown]
# # Lab 1: Commenting Code 🧪🖥
#
# As an engineer, it is important to not only be able to write code, but also to read and understand code written by others. One way to improve your understanding of someone else's code is by adding comments to the code.
#
# Comments are lines of code that are not executed by the computer, but are included to explain what is happening in the code. They can be extremely helpful for anyone reading the code, including yourself, to understand (or remember) the logic and purpose behind each line of code. In Python, any line starting with `#` is a comment. For example, the following line of code has a comment above it explaining what the code does:
#
# ```python
# # store the value 3 in a variable called x
# x = 3
# ```
#
# In this lab assignment, you are given some code to read through, and your task will be to add comments to the code to explain what is happening. Don't worry if the code appears complicated and beyond your current understanding. This is intentional, challenge activities are the best way to learn.
#
# To help you should make use of the Python documentation (https://docs.python.org/3/) as you explore and learn the Python syntax. Most documentation for Python code is hosted online.
#
# The code assigns weekly project groups from a spreadsheet of student names. The code has been split into sections with headers summarizing the code in each cell. You should comment every single line since every single line matters to the computer. Some comments have been provided to you to get you started.
#
# By the end of this assignment, you should have a better understanding of how to read and understand code, as well as how to effectively use comments to explain your code. Good luck!

# %% [markdown]
# ## Import Libraries

# %%
# import the scientific computing library numpy and give it the nickname np
import numpy as np
import random
import csv

# %% [markdown]
# ## Define Student class

# %%
# create a python class called Student
class Student:

    # create a constructor for the Student class that has arguments: leader, partners, and name
    def __init__(self, leader, partners, name):
        # store the name in a data member called self.name
        self.name = name
        self.leader = leader
        self.partners = partners

    # create a method called _leader
    def _leader(self):
        # increment the value of self.leader by 1
        self.leader += 1

# %% [markdown]
# ## Define Group class

# %%
class Groups:
    def __init__(self, group_number, group_size, group_members, group_leader):
        self.group_number = group_number
        self.group_size = group_size
        self.group_member = group_members
        self.group_leader = group_leader

# %% [markdown]
# ## Week class

# %%
class Week:
    def __init__(self, week_number, groups):
        self.week_number = week_number
        self.groups = groups

# %% [markdown]
# ## Load and parse the spreadsheet of filenames

# %%
path = './baby-names-by-state.csv'
# open the file at the specified path for reading and give it the name f
with open(path, 'r') as f:
    # create a csv reader object to read the comma-separated file
    reader = csv.reader(f, delimiter=',')
    headers = next(reader)
    data = np.array(list(reader))

names_ = np.unique(data[:, 2])

# %% [markdown]
# ## Assign the groups

# %%
num_students = 177

num_of_weeks = 5

group_size = 3

# Sets the names for the students
# Names were taken from the list of most common names
names = random.choices(names_, k=num_students)

student_list = []

for name in names:
    student_list.append(Student(0, [], name))

num_groups = len(student_list)//group_size

groups_sizes = []

# If the number of students can be evenly split into groups
if len(student_list) % num_groups == 0:

    group_sizes = [group_size] * num_groups

elif len(student_list) % num_groups <= group_size * .8:
    group_sizes = [group_size] * (num_groups - (len(student_list) % num_groups)) + [
        group_size + 1] * (len(student_list) % num_groups)

week_list = []

for week in range(num_of_weeks):

    leader_number = [student.leader for student in student_list]

    leader_value = sorted(leader_number)[:len(group_sizes)]

    def select_leader(leader_options):
        return np.random.choice(leader_options)

    grouped_students = []
    group_list = []

    for i, _leader_value in enumerate(leader_value):

        leader_number = [student.leader for student in student_list]

        leader_options = np.argwhere(
            np.array(leader_number) == _leader_value).squeeze()

        leader_ = select_leader(leader_options)

        while leader_ in grouped_students:
            leader_ = select_leader(leader_options)

        group_list.append(Groups(i+1,
                                 group_sizes[i],
                                 [student_list[leader_]],
                                 [student_list[leader_]]))

        student_list[leader_]._leader()

        grouped_students.append(leader_)

    for i, group in enumerate(group_list):
        for j in range(group.group_size-1):
            remaining_students = set(
                np.arange(len(student_list)))-set(grouped_students)

            student_num_ = np.random.choice(list(remaining_students))

            group.group_member.append(student_list[student_num_])

            grouped_students.append(student_num_)

    week_list.append(Week(week + 1, group_list))

# %% [markdown]
# ## Print out the groups

# %%
for week in week_list:
    print(f'Week {week.week_number}\n')

    for group in week.groups:
        print(
            f'Group {group.group_number} - lead by {group.group_leader[0].name}')
        print([i.name for i in group.group_member])

    print('\n')
# Out:
# Week 1
#
# Group 1 - lead by Noah
# ['Noah', 'Cheyenne', 'Camila']
# Group 2 - lead by Makenna
# ['Makenna', 'Deanna', 'Addyson']
# Group 3 - lead by Christie
# ['Christie', 'Amir', 'Randall']
# Group 4 - lead by Elizabeth
# ['Elizabeth', 'Everett', 'Clyde']
# Group 5 - lead by Estevan
# ['Estevan', 'Craig', 'Angelique']
# Group 6 - lead by Caden
# ['Caden', 'Carolyn', 'Frederick']
# Group 7 - lead by Marcos
# ['Marcos', 'Talon', 'Zachery']
# Group 8 - lead by Grady
# ['Grady', 'Kristine', 'Sebastian']
# Group 9 - lead by Nia
# ['Nia', 'Paula', 'Melvin']
# Group 10 - lead by Stanley
# ['Stanley', 'Bonnie', 'Leilani']
# Group 11 - lead by Laurie
# ['Laurie', 'Dillon', 'Lilly']
# Group 12 - lead by Claudia
# ['Claudia', 'Dillon', 'Nakia']
# Group 13 - lead by Giselle
# ['Giselle', 'Kendall', 'Adeline']
# Group 14 - lead by Khalil
# ['Khalil', 'Karl', 'Peter']
# Group 15 - lead by Laurel
# ['Laurel', 'Khadijah', 'Maia']
# Group 16 - lead by Kassandra
# ['Kassandra', 'Geraldine', 'Mackenzie']
# Group 17 - lead by Meagan
# ['Meagan', 'George', 'Andy']
# Group 18 - lead by Nadia
# ['Nadia', 'Griffin', 'Curtis']
# Group 19 - lead by Jeanne
# ['Jeanne', 'Esmeralda', 'Jim']
# Group 20 - lead by Dusty
# ['Dusty', 'Anne', 'Andres']
# Group 21 - lead by Noelani
# ['Noelani', 'Jamya', 'Emily']
# Group 22 - lead by Kizzy
# ['Kizzy', 'Cheyenne', 'Krystal']
# Group 23 - lead by Darla
# ['Darla', 'Myra', 'Timothy']
# Group 24 - lead by Steve
# ['Steve', 'Leona', 'Clark']
# Group 25 - lead by Marcos
# ['Marcos', 'Glenda', 'Maribel']
# Group 26 - lead by Saniya
# ['Saniya', 'Owen', 'Jeremiah']
# Group 27 - lead by Kody
# ['Kody', 'Tatyana', 'Laurel']
# Group 28 - lead by Armando
# ['Armando', 'Johnathon', 'Payton']
# Group 29 - lead by Carlos
# ['Carlos', 'Theodore', 'Frances']
# Group 30 - lead by Cheyanne
# ['Cheyanne', 'Nikki', 'Amelia']
# Group 31 - lead by Malik
# ['Malik', 'Charles', 'Carlee']
# Group 32 - lead by Jaquan
# ['Jaquan', 'Angel', 'Hope']
# Group 33 - lead by Shaniya
# ['Shaniya', 'Betsy', 'Leona']
# Group 34 - lead by Kade
# ['Kade', 'Jarvis', 'Kaycee']
# Group 35 - lead by Louise
# ['Louise', 'Lynne', 'Rick']
# Group 36 - lead by Sawyer
# ['Sawyer', 'Shyla', 'Tonia']
# Group 37 - lead by Lakesha
# ['Lakesha', 'Aisha', 'Joanna']
# Group 38 - lead by Izabella
# ['Izabella', 'Shanice', 'Debra']
# Group 39 - lead by Melia
# ['Melia', 'Megan', 'Mary']
# Group 40 - lead by Melissa
# ['Melissa', 'Shayla', 'Gabriela']
# Group 41 - lead by Chandler
# ['Chandler', 'Laurel', 'Thomas']
# Group 42 - lead by Dale
# ['Dale', 'Kali', 'Loretta']
# Group 43 - lead by Harley
# ['Harley', 'Cheyenne', 'Gerard']
# Group 44 - lead by Riley
# ['Riley', 'Kali', 'Bryon']
# Group 45 - lead by Evelyn
# ['Evelyn', 'Brinley', 'Keenan']
# Group 46 - lead by Weston
# ['Weston', 'Natalie', 'Marci']
# Group 47 - lead by Lonnie
# ['Lonnie', 'Meredith', 'Gordon']
# Group 48 - lead by Jazmine
# ['Jazmine', 'Tania', 'Lamar']
# Group 49 - lead by Randall
# ['Randall', 'Chance', 'Charlene']
# Group 50 - lead by Breanna
# ['Breanna', 'Kai', 'Ladonna']
# Group 51 - lead by Janice
# ['Janice', 'Eric', 'Patti']
# Group 52 - lead by Ayden
# ['Ayden', 'Nicolas', 'Shania']
# Group 53 - lead by Mikaela
# ['Mikaela', 'Malcolm', 'Trina']
# Group 54 - lead by Jay
# ['Jay', 'Ansley', 'Hope']
# Group 55 - lead by Matthew
# ['Matthew', 'Baylee', 'Kahealani']
# Group 56 - lead by Kayla
# ['Kayla', 'Kalena', 'Alejandro']
# Group 57 - lead by Debra
# ['Debra', 'Maria', 'Shawn']
# Group 58 - lead by Colten
# ['Colten', 'Sylvia', 'Francisco']
# Group 59 - lead by Marlon
# ['Marlon', 'Cameron', 'Casey']
#
#
# Week 2
#
# Group 1 - lead by Andres
# ['Andres', 'Malcolm', 'Payton']
# Group 2 - lead by Melvin
# ['Melvin', 'Leona', 'Sylvia']
# Group 3 - lead by Khadijah
# ['Khadijah', 'Shyla', 'Christie']
# Group 4 - lead by Paula
# ['Paula', 'Makenna', 'Matthew']
# Group 5 - lead by Geraldine
# ['Geraldine', 'Izabella', 'Weston']
# Group 6 - lead by Carolyn
# ['Carolyn', 'Kayla', 'Glenda']
# Group 7 - lead by Camila
# ['Camila', 'Jeanne', 'Aisha']
# Group 8 - lead by Kali
# ['Kali', 'Nadia', 'Janice']
# Group 9 - lead by Kendall
# ['Kendall', 'Kali', 'Curtis']
# Group 10 - lead by Alejandro
# ['Alejandro', 'Sawyer', 'Clyde']
# Group 11 - lead by Lilly
# ['Lilly', 'Mikaela', 'Clark']
# Group 12 - lead by Jamya
# ['Jamya', 'Kristine', 'Estevan']
# Group 13 - lead by Zachery
# ['Zachery', 'Marcos', 'Kalena']
# Group 14 - lead by Natalie
# ['Natalie', 'Maria', 'Eric']
# Group 15 - lead by Owen
# ['Owen', 'Marlon', 'Malik']
# Group 16 - lead by Frederick
# ['Frederick', 'Chance', 'Noelani']
# Group 17 - lead by Joanna
# ['Joanna', 'Anne', 'Melissa']
# Group 18 - lead by Karl
# ['Karl', 'Jay', 'Charles']
# Group 19 - lead by Leona
# ['Leona', 'Lakesha', 'Deanna']
# Group 20 - lead by George
# ['George', 'Andy', 'Angelique']
# Group 21 - lead by Esmeralda
# ['Esmeralda', 'Bonnie', 'Noah']
# Group 22 - lead by Hope
# ['Hope', 'Nia', 'Nicolas']
# Group 23 - lead by Laurel
# ['Laurel', 'Johnathon', 'Laurel']
# Group 24 - lead by Tonia
# ['Tonia', 'Nikki', 'Megan']
# Group 25 - lead by Laurel
# ['Laurel', 'Shayla', 'Caden']
# Group 26 - lead by Jeremiah
# ['Jeremiah', 'Griffin', 'Dale']
# Group 27 - lead by Kahealani
# ['Kahealani', 'Gabriela', 'Adeline']
# Group 28 - lead by Trina
# ['Trina', 'Mary', 'Ansley']
# Group 29 - lead by Cheyenne
# ['Cheyenne', 'Evelyn', 'Kassandra']
# Group 30 - lead by Jim
# ['Jim', 'Lonnie', 'Bryon']
# Group 31 - lead by Keenan
# ['Keenan', 'Chandler', 'Tania']
# Group 32 - lead by Talon
# ['Talon', 'Shawn', 'Melia']
# Group 33 - lead by Gordon
# ['Gordon', 'Emily', 'Peter']
# Group 34 - lead by Cheyenne
# ['Cheyenne', 'Breanna', 'Myra']
# Group 35 - lead by Carlee
# ['Carlee', 'Francisco', 'Debra']
# Group 36 - lead by Addyson
# ['Addyson', 'Giselle', 'Rick']
# Group 37 - lead by Craig
# ['Craig', 'Ayden', 'Sebastian']
# Group 38 - lead by Thomas
# ['Thomas', 'Jazmine', 'Darla']
# Group 39 - lead by Ladonna
# ['Ladonna', 'Angel', 'Kizzy']
# Group 40 - lead by Randall
# ['Randall', 'Meredith', 'Mackenzie']
# Group 41 - lead by Shania
# ['Shania', 'Stanley', 'Marcos']
# Group 42 - lead by Kai
# ['Kai', 'Saniya', 'Cheyenne']
# Group 43 - lead by Krystal
# ['Krystal', 'Randall', 'Steve']
# Group 44 - lead by Leilani
# ['Leilani', 'Cameron', 'Elizabeth']
# Group 45 - lead by Dillon
# ['Dillon', 'Cheyanne', 'Armando']
# Group 46 - lead by Baylee
# ['Baylee', 'Lynne', 'Maribel']
# Group 47 - lead by Betsy
# ['Betsy', 'Tatyana', 'Louise']
# Group 48 - lead by Amelia
# ['Amelia', 'Charlene', 'Colten']
# Group 49 - lead by Shanice
# ['Shanice', 'Dusty', 'Maia']
# Group 50 - lead by Hope
# ['Hope', 'Grady', 'Debra']
# Group 51 - lead by Amir
# ['Amir', 'Meagan', 'Carlos']
# Group 52 - lead by Everett
# ['Everett', 'Claudia', 'Patti']
# Group 53 - lead by Frances
# ['Frances', 'Jaquan', 'Casey']
# Group 54 - lead by Dillon
# ['Dillon', 'Kade', 'Kaycee']
# Group 55 - lead by Brinley
# ['Brinley', 'Harley', 'Kody']
# Group 56 - lead by Theodore
# ['Theodore', 'Timothy', 'Lamar']
# Group 57 - lead by Marci
# ['Marci', 'Riley', 'Gerard']
# Group 58 - lead by Jarvis
# ['Jarvis', 'Laurie', 'Loretta']
# Group 59 - lead by Nakia
# ['Nakia', 'Khalil', 'Shaniya']
#
#
# Week 3
#
# Group 1 - lead by Tatyana
# ['Tatyana', 'Kahealani', 'Amelia']
# Group 2 - lead by Anne
# ['Anne', 'Christie', 'Randall']
# Group 3 - lead by Leona
# ['Leona', 'Kali', 'Kade']
# Group 4 - lead by Gerard
# ['Gerard', 'Elizabeth', 'Makenna']
# Group 5 - lead by Payton
# ['Payton', 'Riley', 'Carolyn']
# Group 6 - lead by Lynne
# ['Lynne', 'Claudia', 'Khadijah']
# Group 7 - lead by Francisco
# ['Francisco', 'Amir', 'Dusty']
# Group 8 - lead by Griffin
# ['Griffin', 'Laurel', 'Harley']
# Group 9 - lead by Emily
# ['Emily', 'Jazmine', 'Natalie']
# Group 10 - lead by Megan
# ['Megan', 'Lakesha', 'Sawyer']
# Group 11 - lead by Rick
# ['Rick', 'Zachery', 'Meagan']
# Group 12 - lead by Sebastian
# ['Sebastian', 'Khalil', 'Craig']
# Group 13 - lead by Curtis
# ['Curtis', 'Thomas', 'Debra']
# Group 14 - lead by Gabriela
# ['Gabriela', 'Theodore', 'Krystal']
# Group 15 - lead by Loretta
# ['Loretta', 'Shanice', 'Cheyenne']
# Group 16 - lead by Maria
# ['Maria', 'Addyson', 'Paula']
# Group 17 - lead by Cameron
# ['Cameron', 'Gordon', 'Laurie']
# Group 18 - lead by Myra
# ['Myra', 'Dale', 'Esmeralda']
# Group 19 - lead by Eric
# ['Eric', 'Hope', 'Jarvis']
# Group 20 - lead by Debra
# ['Debra', 'Jeremiah', 'Baylee']
# Group 21 - lead by Kaycee
# ['Kaycee', 'Owen', 'Andres']
# Group 22 - lead by Sylvia
# ['Sylvia', 'Hope', 'Dillon']
# Group 23 - lead by Maia
# ['Maia', 'Kayla', 'Saniya']
# Group 24 - lead by Johnathon
# ['Johnathon', 'Giselle', 'Matthew']
# Group 25 - lead by Andy
# ['Andy', 'Cheyanne', 'Louise']
# Group 26 - lead by Nicolas
# ['Nicolas', 'Marcos', 'Leilani']
# Group 27 - lead by Timothy
# ['Timothy', 'Kody', 'Nadia']
# Group 28 - lead by Kali
# ['Kali', 'Deanna', 'Jay']
# Group 29 - lead by Nikki
# ['Nikki', 'Jamya', 'Laurel']
# Group 30 - lead by Adeline
# ['Adeline', 'Marlon', 'Izabella']
# Group 31 - lead by Angel
# ['Angel', 'Noelani', 'Nakia']
# Group 32 - lead by Casey
# ['Casey', 'Brinley', 'Tonia']
# Group 33 - lead by Meredith
# ['Meredith', 'Frederick', 'Everett']
# Group 34 - lead by Mary
# ['Mary', 'Melissa', 'Trina']
# Group 35 - lead by Aisha
# ['Aisha', 'Carlos', 'Ayden']
# Group 36 - lead by Tania
# ['Tania', 'Jeanne', 'Geraldine']
# Group 37 - lead by Malcolm
# ['Malcolm', 'Leona', 'Armando']
# Group 38 - lead by Patti
# ['Patti', 'Melvin', 'Laurel']
# Group 39 - lead by Charlene
# ['Charlene', 'Lilly', 'Jaquan']
# Group 40 - lead by Bryon
# ['Bryon', 'Breanna', 'Keenan']
# Group 41 - lead by Kalena
# ['Kalena', 'Kendall', 'Frances']
# Group 42 - lead by Shyla
# ['Shyla', 'Jim', 'Chandler']
# Group 43 - lead by Shawn
# ['Shawn', 'Cheyenne', 'Lonnie']
# Group 44 - lead by Angelique
# ['Angelique', 'Camila', 'Noah']
# Group 45 - lead by Chance
# ['Chance', 'Darla', 'Joanna']
# Group 46 - lead by Mackenzie
# ['Mackenzie', 'Janice', 'Shaniya']
# Group 47 - lead by Glenda
# ['Glenda', 'Nia', 'Evelyn']
# Group 48 - lead by Lamar
# ['Lamar', 'Weston', 'George']
# Group 49 - lead by Maribel
# ['Maribel', 'Steve', 'Carlee']
# Group 50 - lead by Charles
# ['Charles', 'Alejandro', 'Marci']
# Group 51 - lead by Bonnie
# ['Bonnie', 'Mikaela', 'Stanley']
# Group 52 - lead by Peter
# ['Peter', 'Marcos', 'Kassandra']
# Group 53 - lead by Clyde
# ['Clyde', 'Randall', 'Grady']
# Group 54 - lead by Clark
# ['Clark', 'Melia', 'Betsy']
# Group 55 - lead by Cheyenne
# ['Cheyenne', 'Shania', 'Caden']
# Group 56 - lead by Ansley
# ['Ansley', 'Dillon', 'Malik']
# Group 57 - lead by Shayla
# ['Shayla', 'Karl', 'Kai']
# Group 58 - lead by Kristine
# ['Kristine', 'Kizzy', 'Colten']
# Group 59 - lead by Talon
# ['Talon', 'Estevan', 'Ladonna']
#
#
# Week 4
#
# Group 1 - lead by Debra
# ['Debra', 'Marcos', 'Clyde']
# Group 2 - lead by Maria
# ['Maria', 'Laurie', 'Cameron']
# Group 3 - lead by Louise
# ['Louise', 'Glenda', 'Weston']
# Group 4 - lead by Charlene
# ['Charlene', 'Kaycee', 'Myra']
# Group 5 - lead by Khadijah
# ['Khadijah', 'Harley', 'Amelia']
# Group 6 - lead by Karl
# ['Karl', 'Owen', 'Kassandra']
# Group 7 - lead by Claudia
# ['Claudia', 'Talon', 'Shanice']
# Group 8 - lead by Melvin
# ['Melvin', 'Marci', 'Timothy']
# Group 9 - lead by Betsy
# ['Betsy', 'Jeanne', 'Ladonna']
# Group 10 - lead by Theodore
# ['Theodore', 'Shayla', 'Carlee']
# Group 11 - lead by Lynne
# ['Lynne', 'Nadia', 'Shaniya']
# Group 12 - lead by Griffin
# ['Griffin', 'Bryon', 'Joanna']
# Group 13 - lead by Carolyn
# ['Carolyn', 'Gordon', 'Dillon']
# Group 14 - lead by Krystal
# ['Krystal', 'Riley', 'Shania']
# Group 15 - lead by Mary
# ['Mary', 'Makenna', 'Hope']
# Group 16 - lead by Melia
# ['Melia', 'Matthew', 'Amir']
# Group 17 - lead by Gerard
# ['Gerard', 'Melissa', 'Kahealani']
# Group 18 - lead by Eric
# ['Eric', 'Tania', 'Janice']
# Group 19 - lead by Noah
# ['Noah', 'Esmeralda', 'Clark']
# Group 20 - lead by Meredith
# ['Meredith', 'Nakia', 'Gabriela']
# Group 21 - lead by Jeremiah
# ['Jeremiah', 'Kali', 'Stanley']
# Group 22 - lead by Elizabeth
# ['Elizabeth', 'Camila', 'Izabella']
# Group 23 - lead by Darla
# ['Darla', 'Kayla', 'Natalie']
# Group 24 - lead by Dusty
# ['Dusty', 'Dale', 'Craig']
# Group 25 - lead by Jarvis
# ['Jarvis', 'Kai', 'Angel']
# Group 26 - lead by Kali
# ['Kali', 'Carlos', 'Laurel']
# Group 27 - lead by Cheyenne
# ['Cheyenne', 'Patti', 'Emily']
# Group 28 - lead by Frances
# ['Frances', 'Adeline', 'Thomas']
# Group 29 - lead by Jaquan
# ['Jaquan', 'Addyson', 'Francisco']
# Group 30 - lead by Leona
# ['Leona', 'Cheyanne', 'Deanna']
# Group 31 - lead by Randall
# ['Randall', 'Randall', 'Lakesha']
# Group 32 - lead by Laurel
# ['Laurel', 'Peter', 'Kade']
# Group 33 - lead by Lonnie
# ['Lonnie', 'Trina', 'Marlon']
# Group 34 - lead by Sebastian
# ['Sebastian', 'Hope', 'Nikki']
# Group 35 - lead by Brinley
# ['Brinley', 'Leilani', 'Meagan']
# Group 36 - lead by Sylvia
# ['Sylvia', 'Caden', 'Tonia']
# Group 37 - lead by Maribel
# ['Maribel', 'Cheyenne', 'Giselle']
# Group 38 - lead by Christie
# ['Christie', 'Loretta', 'Jim']
# Group 39 - lead by Jay
# ['Jay', 'Ayden', 'Aisha']
# Group 40 - lead by Casey
# ['Casey', 'Breanna', 'Rick']
# Group 41 - lead by Colten
# ['Colten', 'Johnathon', 'Malik']
# Group 42 - lead by Laurel
# ['Laurel', 'Dillon', 'Debra']
# Group 43 - lead by Noelani
# ['Noelani', 'Paula', 'Alejandro']
# Group 44 - lead by Frederick
# ['Frederick', 'Payton', 'Shyla']
# Group 45 - lead by Geraldine
# ['Geraldine', 'Khalil', 'Jazmine']
# Group 46 - lead by Angelique
# ['Angelique', 'Zachery', 'Kalena']
# Group 47 - lead by Cheyenne
# ['Cheyenne', 'Estevan', 'Kody']
# Group 48 - lead by Marcos
# ['Marcos', 'Kizzy', 'Malcolm']
# Group 49 - lead by Ansley
# ['Ansley', 'Chance', 'Tatyana']
# Group 50 - lead by Nicolas
# ['Nicolas', 'Lamar', 'Saniya']
# Group 51 - lead by Baylee
# ['Baylee', 'Evelyn', 'Keenan']
# Group 52 - lead by Everett
# ['Everett', 'Mikaela', 'Bonnie']
# Group 53 - lead by Nia
# ['Nia', 'Kristine', 'George']
# Group 54 - lead by Grady
# ['Grady', 'Armando', 'Andres']
# Group 55 - lead by Steve
# ['Steve', 'Maia', 'Jamya']
# Group 56 - lead by Lilly
# ['Lilly', 'Kendall', 'Leona']
# Group 57 - lead by Andy
# ['Andy', 'Chandler', 'Anne']
# Group 58 - lead by Sawyer
# ['Sawyer', 'Charles', 'Curtis']
# Group 59 - lead by Megan
# ['Megan', 'Shawn', 'Mackenzie']
#
#
# Week 5
#
# Group 1 - lead by Shyla
# ['Shyla', 'Tonia', 'Estevan']
# Group 2 - lead by Peter
# ['Peter', 'Meagan', 'Melia']
# Group 3 - lead by Zachery
# ['Zachery', 'Armando', 'Lynne']
# Group 4 - lead by Leilani
# ['Leilani', 'Cameron', 'Melissa']
# Group 5 - lead by Gabriela
# ['Gabriela', 'Krystal', 'Noelani']
# Group 6 - lead by Weston
# ['Weston', 'Riley', 'Leona']
# Group 7 - lead by Alejandro
# ['Alejandro', 'Karl', 'Laurel']
# Group 8 - lead by Giselle
# ['Giselle', 'Cheyanne', 'Kalena']
# Group 9 - lead by Malik
# ['Malik', 'Myra', 'Harley']
# Group 10 - lead by Shawn
# ['Shawn', 'Charlene', 'Stanley']
# Group 11 - lead by Hope
# ['Hope', 'Dusty', 'Claudia']
# Group 12 - lead by Jazmine
# ['Jazmine', 'Cheyenne', 'Louise']
# Group 13 - lead by Angel
# ['Angel', 'Natalie', 'Payton']
# Group 14 - lead by Francisco
# ['Francisco', 'Laurel', 'Megan']
# Group 15 - lead by Addyson
# ['Addyson', 'Debra', 'Everett']
# Group 16 - lead by Izabella
# ['Izabella', 'Lonnie', 'Kaycee']
# Group 17 - lead by George
# ['George', 'Nia', 'Paula']
# Group 18 - lead by Bonnie
# ['Bonnie', 'Malcolm', 'Geraldine']
# Group 19 - lead by Carlee
# ['Carlee', 'Craig', 'Sawyer']
# Group 20 - lead by Clyde
# ['Clyde', 'Leona', 'Meredith']
# Group 21 - lead by Lakesha
# ['Lakesha', 'Ansley', 'Kali']
# Group 22 - lead by Marci
# ['Marci', 'Laurel', 'Randall']
# Group 23 - lead by Bryon
# ['Bryon', 'Maribel', 'Timothy']
# Group 24 - lead by Thomas
# ['Thomas', 'Khalil', 'Baylee']
# Group 25 - lead by Esmeralda
# ['Esmeralda', 'Grady', 'Debra']
# Group 26 - lead by Dillon
# ['Dillon', 'Elizabeth', 'Charles']
# Group 27 - lead by Shania
# ['Shania', 'Kristine', 'Cheyenne']
# Group 28 - lead by Anne
# ['Anne', 'Rick', 'Griffin']
# Group 29 - lead by Ladonna
# ['Ladonna', 'Dillon', 'Andy']
# Group 30 - lead by Loretta
# ['Loretta', 'Curtis', 'Saniya']
# Group 31 - lead by Lamar
# ['Lamar', 'Owen', 'Jeanne']
# Group 32 - lead by Adeline
# ['Adeline', 'Jaquan', 'Frances']
# Group 33 - lead by Andres
# ['Andres', 'Jarvis', 'Kizzy']
# Group 34 - lead by Nikki
# ['Nikki', 'Kahealani', 'Christie']
# Group 35 - lead by Johnathon
# ['Johnathon', 'Brinley', 'Gordon']
# Group 36 - lead by Kayla
# ['Kayla', 'Khadijah', 'Lilly']
# Group 37 - lead by Trina
# ['Trina', 'Sylvia', 'Emily']
# Group 38 - lead by Clark
# ['Clark', 'Kade', 'Kali']
# Group 39 - lead by Shayla
# ['Shayla', 'Melvin', 'Chandler']
# Group 40 - lead by Nadia
# ['Nadia', 'Kai', 'Jeremiah']
# Group 41 - lead by Carlos
# ['Carlos', 'Mary', 'Jay']
# Group 42 - lead by Shaniya
# ['Shaniya', 'Joanna', 'Kassandra']
# Group 43 - lead by Mackenzie
# ['Mackenzie', 'Angelique', 'Cheyenne']
# Group 44 - lead by Caden
# ['Caden', 'Keenan', 'Eric']
# Group 45 - lead by Laurie
# ['Laurie', 'Maia', 'Marcos']
# Group 46 - lead by Tatyana
# ['Tatyana', 'Talon', 'Casey']
# Group 47 - lead by Chance
# ['Chance', 'Nicolas', 'Steve']
# Group 48 - lead by Patti
# ['Patti', 'Frederick', 'Colten']
# Group 49 - lead by Janice
# ['Janice', 'Kendall', 'Matthew']
# Group 50 - lead by Kody
# ['Kody', 'Glenda', 'Carolyn']
# Group 51 - lead by Camila
# ['Camila', 'Marcos', 'Theodore']
# Group 52 - lead by Tania
# ['Tania', 'Darla', 'Ayden']
# Group 53 - lead by Mikaela
# ['Mikaela', 'Shanice', 'Gerard']
# Group 54 - lead by Nakia
# ['Nakia', 'Amelia', 'Noah']
# Group 55 - lead by Jim
# ['Jim', 'Maria', 'Deanna']
# Group 56 - lead by Hope
# ['Hope', 'Breanna', 'Jamya']
# Group 57 - lead by Marlon
# ['Marlon', 'Makenna', 'Dale']
# Group 58 - lead by Randall
# ['Randall', 'Sebastian', 'Amir']
# Group 59 - lead by Evelyn
# ['Evelyn', 'Betsy', 'Aisha']
