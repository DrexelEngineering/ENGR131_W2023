# %% [markdown]
# # Lab 1: Commenting Code 🧪🖥
#
# As an engineer, it is important to not only be able to write code, but also to read and understand code written by others. One way to improve your understanding of someone else's code is by adding comments to the code.
#
# Comments are lines of code that are not executed by the computer, but are included to explain what is happening in the code. They can be extremely helpful for anyone reading the code, including yourself, to understand (or remember) the logic and purpose behind each line of code. In Python, any line starting with `#` is a comment. For example, the following line of code has a comment above it explaining what the code does:
#
# ```python
# # store the value 3 in a variable called x
# x = 3
# ```
#
# In this lab assignment, you are given some code to read through, and your task will be to add comments to the code to explain what is happening. Don't worry if the code appears complicated and beyond your current understanding. This is intentional, challenge activities are the best way to learn.
#
# To help you should make use of the Python documentation (https://docs.python.org/3/) as you explore and learn the Python syntax. Most documentation for Python code is hosted online.
#
# The code assigns weekly project groups from a spreadsheet of student names. The code has been split into sections with headers summarizing the code in each cell. You should comment every single line since every single line matters to the computer. Some comments have been provided to you to get you started.
#
# By the end of this assignment, you should have a better understanding of how to read and understand code, as well as how to effectively use comments to explain your code. Good luck!

# %% [markdown]
# ## Import Libraries

# %%
# import the scientific computing library numpy and give it the nickname np
import numpy as np
import random
import csv

# %% [markdown]
# ## Define Student class

# %%
# create a python class called Student
class Student:

    # create a constructor for the Student class that has arguments: leader, partners, and name
    def __init__(self, leader, partners, name):
        # store the name in a data member called self.name
        self.name = name
        self.leader = leader
        self.partners = partners

    # create a method called _leader
    def _leader(self):
        # increment the value of self.leader by 1
        self.leader += 1

# %% [markdown]
# ## Define Group class

# %%
class Groups:
    def __init__(self, group_number, group_size, group_members, group_leader):
        self.group_number = group_number
        self.group_size = group_size
        self.group_member = group_members
        self.group_leader = group_leader

# %% [markdown]
# ## Week class

# %%
class Week:
    def __init__(self, week_number, groups):
        self.week_number = week_number
        self.groups = groups

# %% [markdown]
# ## Load and parse the spreadsheet of filenames

# %%
path = './baby-names-by-state.csv'
# open the file at the specified path for reading and give it the name f
with open(path, 'r') as f:
    # create a csv reader object to read the comma-separated file
    reader = csv.reader(f, delimiter=',')
    headers = next(reader)
    data = np.array(list(reader))

names_ = np.unique(data[:, 2])

# %% [markdown]
# ## Assign the groups

# %%
num_students = 177

num_of_weeks = 5

group_size = 3

# Sets the names for the students
# Names were taken from the list of most common names
names = random.choices(names_, k=num_students)

student_list = []

for name in names:
    student_list.append(Student(0, [], name))

num_groups = len(student_list)//group_size

groups_sizes = []

# If the number of students can be evenly split into groups
if len(student_list) % num_groups == 0:

    group_sizes = [group_size] * num_groups

elif len(student_list) % num_groups <= group_size * .8:
    group_sizes = [group_size] * (num_groups - (len(student_list) % num_groups)) + [
        group_size + 1] * (len(student_list) % num_groups)

week_list = []

for week in range(num_of_weeks):

    leader_number = [student.leader for student in student_list]

    leader_value = sorted(leader_number)[:len(group_sizes)]

    def select_leader(leader_options):
        return np.random.choice(leader_options)

    grouped_students = []
    group_list = []

    for i, _leader_value in enumerate(leader_value):

        leader_number = [student.leader for student in student_list]

        leader_options = np.argwhere(
            np.array(leader_number) == _leader_value).squeeze()

        leader_ = select_leader(leader_options)

        while leader_ in grouped_students:
            leader_ = select_leader(leader_options)

        group_list.append(Groups(i+1,
                                 group_sizes[i],
                                 [student_list[leader_]],
                                 [student_list[leader_]]))

        student_list[leader_]._leader()

        grouped_students.append(leader_)

    for i, group in enumerate(group_list):
        for j in range(group.group_size-1):
            remaining_students = set(
                np.arange(len(student_list)))-set(grouped_students)

            student_num_ = np.random.choice(list(remaining_students))

            group.group_member.append(student_list[student_num_])

            grouped_students.append(student_num_)

    week_list.append(Week(week + 1, group_list))

# %% [markdown]
# ## Print out the groups

# %%
for week in week_list:
    print(f'Week {week.week_number}\n')

    for group in week.groups:
        print(
            f'Group {group.group_number} - lead by {group.group_leader[0].name}')
        print([i.name for i in group.group_member])

    print('\n')
# Out:
# Week 1
#
# Group 1 - lead by Jefferson
# ['Jefferson', 'Tabatha', 'Kayden']
# Group 2 - lead by Melissa
# ['Melissa', 'Lynette', 'Grayson']
# Group 3 - lead by Tristan
# ['Tristan', 'Karl', 'Elliot']
# Group 4 - lead by Luke
# ['Luke', 'Randal', 'Mitchell']
# Group 5 - lead by Dane
# ['Dane', 'Sienna', 'Tyrell']
# Group 6 - lead by Tammie
# ['Tammie', 'Katie', 'Ann']
# Group 7 - lead by Billie
# ['Billie', 'Corbin', 'Audra']
# Group 8 - lead by Jimmie
# ['Jimmie', 'Brandy', 'Jaylon']
# Group 9 - lead by Timmy
# ['Timmy', 'Jaheim', 'Melinda']
# Group 10 - lead by Kanani
# ['Kanani', 'Rodney', 'Harley']
# Group 11 - lead by Chelsie
# ['Chelsie', 'Gerald', 'Kaitlin']
# Group 12 - lead by Cash
# ['Cash', 'Sarah', 'Lucy']
# Group 13 - lead by Blaze
# ['Blaze', 'Allyson', 'Tyler']
# Group 14 - lead by Janelle
# ['Janelle', 'Kailey', 'Marley']
# Group 15 - lead by Lisa
# ['Lisa', 'Laurel', 'Pam']
# Group 16 - lead by Donovan
# ['Donovan', 'Angelo', 'Boyd']
# Group 17 - lead by Lynne
# ['Lynne', 'Levi', 'Bella']
# Group 18 - lead by Ty
# ['Ty', 'Monique', 'Aniyah']
# Group 19 - lead by Presley
# ['Presley', 'Wade', 'Irene']
# Group 20 - lead by Eleanor
# ['Eleanor', 'Frank', 'Tatum']
# Group 21 - lead by Blaine
# ['Blaine', 'Alicia', 'Mandy']
# Group 22 - lead by Malcolm
# ['Malcolm', 'Katharine', 'Brooklynn']
# Group 23 - lead by Moshe
# ['Moshe', 'Emely', 'Heaven']
# Group 24 - lead by Lena
# ['Lena', 'Heath', 'Makayla']
# Group 25 - lead by Ellie
# ['Ellie', 'Tamika', 'Elliot']
# Group 26 - lead by Amya
# ['Amya', 'Shawn', 'Ruby']
# Group 27 - lead by Levi
# ['Levi', 'Floyd', 'Sabrina']
# Group 28 - lead by Antwan
# ['Antwan', 'Darlene', 'Rachael']
# Group 29 - lead by Angela
# ['Angela', 'Bill', 'Anne']
# Group 30 - lead by Kadence
# ['Kadence', 'Frederick', 'Billy']
# Group 31 - lead by Jean
# ['Jean', 'Raul', 'Brendon']
# Group 32 - lead by Nikita
# ['Nikita', 'Cristian', 'Ivy']
# Group 33 - lead by Esperanza
# ['Esperanza', 'Sarah', 'Roy']
# Group 34 - lead by Spencer
# ['Spencer', 'Aisha', 'Kimberly']
# Group 35 - lead by Keira
# ['Keira', 'Quinn', 'Brett']
# Group 36 - lead by Bronson
# ['Bronson', 'Delilah', 'Scott']
# Group 37 - lead by Debora
# ['Debora', 'Kimberley', 'Esperanza']
# Group 38 - lead by Tamika
# ['Tamika', 'Echo', 'Bronson']
# Group 39 - lead by Blaze
# ['Blaze', 'Ezekiel', 'Kekoa']
# Group 40 - lead by Donnie
# ['Donnie', 'Kawena', 'Hazel']
# Group 41 - lead by Ruby
# ['Ruby', 'Liana', 'Kade']
# Group 42 - lead by Franklin
# ['Franklin', 'Louis', 'Cheryl']
# Group 43 - lead by Ashleigh
# ['Ashleigh', 'Shelbi', 'Jaelyn']
# Group 44 - lead by Jaelyn
# ['Jaelyn', 'Shyla', 'Allie']
# Group 45 - lead by Makayla
# ['Makayla', 'Belinda', 'Marianne']
# Group 46 - lead by Jane
# ['Jane', 'Karen', 'Brendon']
# Group 47 - lead by Bernadette
# ['Bernadette', 'Alvin', 'Staci']
# Group 48 - lead by Angelique
# ['Angelique', 'Reagan', 'Kim']
# Group 49 - lead by Willa
# ['Willa', 'Lorrie', 'Roderick']
# Group 50 - lead by Kristine
# ['Kristine', 'Alyson', 'Alicia']
# Group 51 - lead by Gwen
# ['Gwen', 'Jaxon', 'Chandler']
# Group 52 - lead by Frances
# ['Frances', 'Hunter', 'Miriam']
# Group 53 - lead by Keenan
# ['Keenan', 'Daquan', 'Stephon']
# Group 54 - lead by Tony
# ['Tony', 'Chantelle', 'Santiago']
# Group 55 - lead by Braylon
# ['Braylon', 'Mariana', 'Glenda']
# Group 56 - lead by Justice
# ['Justice', 'Aubree', 'Denzel']
# Group 57 - lead by Candice
# ['Candice', 'Jacoby', 'Tyson']
# Group 58 - lead by Dorothy
# ['Dorothy', 'Janay', 'Angelica']
# Group 59 - lead by Delaney
# ['Delaney', 'James', 'Joey']
#
#
# Week 2
#
# Group 1 - lead by Jaylon
# ['Jaylon', 'Alicia', 'Dorothy']
# Group 2 - lead by Raul
# ['Raul', 'Makayla', 'Ruby']
# Group 3 - lead by Kekoa
# ['Kekoa', 'Corbin', 'Monique']
# Group 4 - lead by Laurel
# ['Laurel', 'Esperanza', 'Jane']
# Group 5 - lead by Katharine
# ['Katharine', 'Donnie', 'Jaheim']
# Group 6 - lead by Esperanza
# ['Esperanza', 'Tatum', 'Daquan']
# Group 7 - lead by Brett
# ['Brett', 'Angela', 'Delaney']
# Group 8 - lead by Miriam
# ['Miriam', 'Tristan', 'Tammie']
# Group 9 - lead by Brooklynn
# ['Brooklynn', 'Aisha', 'Levi']
# Group 10 - lead by Mariana
# ['Mariana', 'Joey', 'Tyrell']
# Group 11 - lead by Alicia
# ['Alicia', 'Lena', 'Jean']
# Group 12 - lead by Floyd
# ['Floyd', 'Chandler', 'Tony']
# Group 13 - lead by Mitchell
# ['Mitchell', 'Eleanor', 'Moshe']
# Group 14 - lead by Karl
# ['Karl', 'Janay', 'Kimberly']
# Group 15 - lead by Heath
# ['Heath', 'Justice', 'Cristian']
# Group 16 - lead by Lucy
# ['Lucy', 'Blaze', 'Ellie']
# Group 17 - lead by Lynette
# ['Lynette', 'Frank', 'Billie']
# Group 18 - lead by Ann
# ['Ann', 'James', 'Levi']
# Group 19 - lead by Hunter
# ['Hunter', 'Shawn', 'Elliot']
# Group 20 - lead by Boyd
# ['Boyd', 'Chantelle', 'Delilah']
# Group 21 - lead by Randal
# ['Randal', 'Brendon', 'Mandy']
# Group 22 - lead by Staci
# ['Staci', 'Jaxon', 'Kadence']
# Group 23 - lead by Kimberley
# ['Kimberley', 'Reagan', 'Jimmie']
# Group 24 - lead by Marianne
# ['Marianne', 'Timmy', 'Antwan']
# Group 25 - lead by Darlene
# ['Darlene', 'Donovan', 'Emely']
# Group 26 - lead by Harley
# ['Harley', 'Braylon', 'Tyler']
# Group 27 - lead by Rodney
# ['Rodney', 'Ruby', 'Cheryl']
# Group 28 - lead by Kim
# ['Kim', 'Irene', 'Spencer']
# Group 29 - lead by Sarah
# ['Sarah', 'Jefferson', 'Keira']
# Group 30 - lead by Stephon
# ['Stephon', 'Luke', 'Chelsie']
# Group 31 - lead by Sienna
# ['Sienna', 'Tabatha', 'Angelica']
# Group 32 - lead by Allyson
# ['Allyson', 'Rachael', 'Ty']
# Group 33 - lead by Makayla
# ['Makayla', 'Blaze', 'Franklin']
# Group 34 - lead by Karen
# ['Karen', 'Aniyah', 'Kristine']
# Group 35 - lead by Roy
# ['Roy', 'Billy', 'Dane']
# Group 36 - lead by Kade
# ['Kade', 'Ezekiel', 'Kanani']
# Group 37 - lead by Kaitlin
# ['Kaitlin', 'Nikita', 'Lynne']
# Group 38 - lead by Denzel
# ['Denzel', 'Wade', 'Frances']
# Group 39 - lead by Kawena
# ['Kawena', 'Lorrie', 'Bella']
# Group 40 - lead by Pam
# ['Pam', 'Sabrina', 'Gwen']
# Group 41 - lead by Marley
# ['Marley', 'Brendon', 'Kayden']
# Group 42 - lead by Allie
# ['Allie', 'Santiago', 'Echo']
# Group 43 - lead by Jacoby
# ['Jacoby', 'Quinn', 'Hazel']
# Group 44 - lead by Shyla
# ['Shyla', 'Grayson', 'Belinda']
# Group 45 - lead by Alvin
# ['Alvin', 'Scott', 'Glenda']
# Group 46 - lead by Ivy
# ['Ivy', 'Janelle', 'Debora']
# Group 47 - lead by Louis
# ['Louis', 'Melinda', 'Bernadette']
# Group 48 - lead by Bill
# ['Bill', 'Cash', 'Ashleigh']
# Group 49 - lead by Brandy
# ['Brandy', 'Tamika', 'Melissa']
# Group 50 - lead by Tamika
# ['Tamika', 'Amya', 'Heaven']
# Group 51 - lead by Gerald
# ['Gerald', 'Alyson', 'Angelo']
# Group 52 - lead by Katie
# ['Katie', 'Angelique', 'Willa']
# Group 53 - lead by Anne
# ['Anne', 'Kailey', 'Bronson']
# Group 54 - lead by Liana
# ['Liana', 'Keenan', 'Candice']
# Group 55 - lead by Roderick
# ['Roderick', 'Audra', 'Presley']
# Group 56 - lead by Frederick
# ['Frederick', 'Jaelyn', 'Shelbi']
# Group 57 - lead by Bronson
# ['Bronson', 'Blaine', 'Jaelyn']
# Group 58 - lead by Sarah
# ['Sarah', 'Malcolm', 'Lisa']
# Group 59 - lead by Elliot
# ['Elliot', 'Tyson', 'Aubree']
#
#
# Week 3
#
# Group 1 - lead by Alyson
# ['Alyson', 'Elliot', 'Justice']
# Group 2 - lead by Billy
# ['Billy', 'Ivy', 'Cash']
# Group 3 - lead by Angelo
# ['Angelo', 'Liana', 'Floyd']
# Group 4 - lead by Jaheim
# ['Jaheim', 'Blaze', 'Brooklynn']
# Group 5 - lead by Janay
# ['Janay', 'Bernadette', 'Marley']
# Group 6 - lead by Wade
# ['Wade', 'Franklin', 'Malcolm']
# Group 7 - lead by Scott
# ['Scott', 'Frederick', 'Tamika']
# Group 8 - lead by Quinn
# ['Quinn', 'Billie', 'Tamika']
# Group 9 - lead by Tyrell
# ['Tyrell', 'Darlene', 'Keenan']
# Group 10 - lead by Brendon
# ['Brendon', 'Jacoby', 'Antwan']
# Group 11 - lead by Chantelle
# ['Chantelle', 'Anne', 'Shyla']
# Group 12 - lead by Angelica
# ['Angelica', 'Brandy', 'Kekoa']
# Group 13 - lead by Ezekiel
# ['Ezekiel', 'Sarah', 'Mitchell']
# Group 14 - lead by Hazel
# ['Hazel', 'Kade', 'Amya']
# Group 15 - lead by Reagan
# ['Reagan', 'Miriam', 'Jane']
# Group 16 - lead by Melinda
# ['Melinda', 'Glenda', 'Sienna']
# Group 17 - lead by Brendon
# ['Brendon', 'Denzel', 'Alicia']
# Group 18 - lead by Aniyah
# ['Aniyah', 'Blaze', 'Staci']
# Group 19 - lead by Alicia
# ['Alicia', 'Nikita', 'Donnie']
# Group 20 - lead by Jaxon
# ['Jaxon', 'Heath', 'Donovan']
# Group 21 - lead by Kailey
# ['Kailey', 'Tristan', 'Sarah']
# Group 22 - lead by Tyson
# ['Tyson', 'Debora', 'Bill']
# Group 23 - lead by James
# ['James', 'Delaney', 'Dane']
# Group 24 - lead by Daquan
# ['Daquan', 'Angela', 'Boyd']
# Group 25 - lead by Mandy
# ['Mandy', 'Karl', 'Kristine']
# Group 26 - lead by Cheryl
# ['Cheryl', 'Marianne', 'Mariana']
# Group 27 - lead by Corbin
# ['Corbin', 'Kaitlin', 'Ann']
# Group 28 - lead by Rachael
# ['Rachael', 'Allyson', 'Ellie']
# Group 29 - lead by Aubree
# ['Aubree', 'Lynne', 'Pam']
# Group 30 - lead by Joey
# ['Joey', 'Jean', 'Gerald']
# Group 31 - lead by Emely
# ['Emely', 'Lisa', 'Esperanza']
# Group 32 - lead by Irene
# ['Irene', 'Raul', 'Laurel']
# Group 33 - lead by Monique
# ['Monique', 'Angelique', 'Allie']
# Group 34 - lead by Chandler
# ['Chandler', 'Presley', 'Melissa']
# Group 35 - lead by Aisha
# ['Aisha', 'Kimberley', 'Jaylon']
# Group 36 - lead by Delilah
# ['Delilah', 'Eleanor', 'Jimmie']
# Group 37 - lead by Lorrie
# ['Lorrie', 'Bronson', 'Karen']
# Group 38 - lead by Bella
# ['Bella', 'Bronson', 'Kadence']
# Group 39 - lead by Kimberly
# ['Kimberly', 'Dorothy', 'Levi']
# Group 40 - lead by Heaven
# ['Heaven', 'Randal', 'Ashleigh']
# Group 41 - lead by Echo
# ['Echo', 'Tammie', 'Blaine']
# Group 42 - lead by Cristian
# ['Cristian', 'Katie', 'Chelsie']
# Group 43 - lead by Audra
# ['Audra', 'Roderick', 'Kawena']
# Group 44 - lead by Sabrina
# ['Sabrina', 'Gwen', 'Roy']
# Group 45 - lead by Jaelyn
# ['Jaelyn', 'Timmy', 'Candice']
# Group 46 - lead by Tabatha
# ['Tabatha', 'Katharine', 'Kim']
# Group 47 - lead by Shelbi
# ['Shelbi', 'Esperanza', 'Alvin']
# Group 48 - lead by Ruby
# ['Ruby', 'Louis', 'Hunter']
# Group 49 - lead by Levi
# ['Levi', 'Moshe', 'Makayla']
# Group 50 - lead by Tatum
# ['Tatum', 'Spencer', 'Lynette']
# Group 51 - lead by Belinda
# ['Belinda', 'Tony', 'Braylon']
# Group 52 - lead by Kayden
# ['Kayden', 'Lena', 'Lucy']
# Group 53 - lead by Tyler
# ['Tyler', 'Kanani', 'Jefferson']
# Group 54 - lead by Santiago
# ['Santiago', 'Brett', 'Willa']
# Group 55 - lead by Shawn
# ['Shawn', 'Janelle', 'Keira']
# Group 56 - lead by Grayson
# ['Grayson', 'Luke', 'Harley']
# Group 57 - lead by Elliot
# ['Elliot', 'Frances', 'Jaelyn']
# Group 58 - lead by Frank
# ['Frank', 'Ruby', 'Makayla']
# Group 59 - lead by Rodney
# ['Rodney', 'Ty', 'Stephon']
#
#
# Week 4
#
# Group 1 - lead by Justice
# ['Justice', 'Braylon', 'Boyd']
# Group 2 - lead by Blaze
# ['Blaze', 'Debora', 'Spencer']
# Group 3 - lead by Gerald
# ['Gerald', 'Kailey', 'Brett']
# Group 4 - lead by Levi
# ['Levi', 'Belinda', 'Aniyah']
# Group 5 - lead by Janelle
# ['Janelle', 'Melissa', 'Angelica']
# Group 6 - lead by Jaxon
# ['Jaxon', 'Ty', 'Karen']
# Group 7 - lead by Nikita
# ['Nikita', 'Ruby', 'Rachael']
# Group 8 - lead by Billie
# ['Billie', 'Cash', 'Willa']
# Group 9 - lead by Chelsie
# ['Chelsie', 'Mitchell', 'Hazel']
# Group 10 - lead by Sarah
# ['Sarah', 'Louis', 'Tyler']
# Group 11 - lead by Kekoa
# ['Kekoa', 'Liana', 'Tammie']
# Group 12 - lead by Jane
# ['Jane', 'Timmy', 'Shawn']
# Group 13 - lead by Jaheim
# ['Jaheim', 'Bill', 'Candice']
# Group 14 - lead by Jimmie
# ['Jimmie', 'Staci', 'Anne']
# Group 15 - lead by Denzel
# ['Denzel', 'Makayla', 'Lynette']
# Group 16 - lead by Delaney
# ['Delaney', 'Monique', 'Frank']
# Group 17 - lead by Allie
# ['Allie', 'Keira', 'Glenda']
# Group 18 - lead by Donnie
# ['Donnie', 'Corbin', 'Rodney']
# Group 19 - lead by Grayson
# ['Grayson', 'Jaelyn', 'Jean']
# Group 20 - lead by Eleanor
# ['Eleanor', 'Lucy', 'Bronson']
# Group 21 - lead by Marianne
# ['Marianne', 'Kadence', 'Joey']
# Group 22 - lead by Echo
# ['Echo', 'Lorrie', 'Tamika']
# Group 23 - lead by Luke
# ['Luke', 'Esperanza', 'Ashleigh']
# Group 24 - lead by Sarah
# ['Sarah', 'Janay', 'Ellie']
# Group 25 - lead by Mariana
# ['Mariana', 'Cheryl', 'Kanani']
# Group 26 - lead by Stephon
# ['Stephon', 'Jacoby', 'Santiago']
# Group 27 - lead by Sienna
# ['Sienna', 'Jaylon', 'Tristan']
# Group 28 - lead by Pam
# ['Pam', 'Brendon', 'Tamika']
# Group 29 - lead by Delilah
# ['Delilah', 'Ivy', 'Angelique']
# Group 30 - lead by Moshe
# ['Moshe', 'Katie', 'Frederick']
# Group 31 - lead by Blaine
# ['Blaine', 'Alvin', 'Angela']
# Group 32 - lead by Amya
# ['Amya', 'Tyson', 'Quinn']
# Group 33 - lead by Marley
# ['Marley', 'Lisa', 'Audra']
# Group 34 - lead by Dane
# ['Dane', 'Mandy', 'Emely']
# Group 35 - lead by Alicia
# ['Alicia', 'Chantelle', 'Antwan']
# Group 36 - lead by Melinda
# ['Melinda', 'Scott', 'Ruby']
# Group 37 - lead by Darlene
# ['Darlene', 'Jaelyn', 'Elliot']
# Group 38 - lead by Alicia
# ['Alicia', 'Karl', 'Raul']
# Group 39 - lead by Malcolm
# ['Malcolm', 'Levi', 'Chandler']
# Group 40 - lead by Bernadette
# ['Bernadette', 'Kimberly', 'Alyson']
# Group 41 - lead by Hunter
# ['Hunter', 'Randal', 'Dorothy']
# Group 42 - lead by Roderick
# ['Roderick', 'Gwen', 'Wade']
# Group 43 - lead by Bella
# ['Bella', 'Floyd', 'Shelbi']
# Group 44 - lead by Katharine
# ['Katharine', 'Laurel', 'Heath']
# Group 45 - lead by Allyson
# ['Allyson', 'James', 'Lena']
# Group 46 - lead by Donovan
# ['Donovan', 'Bronson', 'Tyrell']
# Group 47 - lead by Daquan
# ['Daquan', 'Elliot', 'Frances']
# Group 48 - lead by Kayden
# ['Kayden', 'Lynne', 'Blaze']
# Group 49 - lead by Tony
# ['Tony', 'Harley', 'Angelo']
# Group 50 - lead by Reagan
# ['Reagan', 'Cristian', 'Keenan']
# Group 51 - lead by Jefferson
# ['Jefferson', 'Aubree', 'Roy']
# Group 52 - lead by Presley
# ['Presley', 'Brooklynn', 'Ann']
# Group 53 - lead by Makayla
# ['Makayla', 'Brandy', 'Billy']
# Group 54 - lead by Ezekiel
# ['Ezekiel', 'Sabrina', 'Kristine']
# Group 55 - lead by Brendon
# ['Brendon', 'Tatum', 'Kim']
# Group 56 - lead by Shyla
# ['Shyla', 'Franklin', 'Kade']
# Group 57 - lead by Miriam
# ['Miriam', 'Kimberley', 'Kaitlin']
# Group 58 - lead by Esperanza
# ['Esperanza', 'Irene', 'Aisha']
# Group 59 - lead by Heaven
# ['Heaven', 'Tabatha', 'Kawena']
#
#
# Week 5
#
# Group 1 - lead by Shyla
# ['Shyla', 'Alicia', 'Glenda']
# Group 2 - lead by Angelique
# ['Angelique', 'Aisha', 'Rachael']
# Group 3 - lead by Monique
# ['Monique', 'Janelle', 'Mariana']
# Group 4 - lead by Cash
# ['Cash', 'Darlene', 'Aubree']
# Group 5 - lead by Heath
# ['Heath', 'Billie', 'Denzel']
# Group 6 - lead by Kimberley
# ['Kimberley', 'Billy', 'Tony']
# Group 7 - lead by Brandy
# ['Brandy', 'Bernadette', 'Jefferson']
# Group 8 - lead by Corbin
# ['Corbin', 'Sarah', 'Eleanor']
# Group 9 - lead by Randal
# ['Randal', 'Brendon', 'Scott']
# Group 10 - lead by Lynette
# ['Lynette', 'Kimberly', 'Makayla']
# Group 11 - lead by Kristine
# ['Kristine', 'Nikita', 'Angela']
# Group 12 - lead by Irene
# ['Irene', 'Reagan', 'Levi']
# Group 13 - lead by Ashleigh
# ['Ashleigh', 'Blaze', 'Sarah']
# Group 14 - lead by Joey
# ['Joey', 'Moshe', 'Tabatha']
# Group 15 - lead by Ruby
# ['Ruby', 'Marianne', 'Anne']
# Group 16 - lead by Tatum
# ['Tatum', 'Luke', 'Amya']
# Group 17 - lead by Tammie
# ['Tammie', 'Angelo', 'Levi']
# Group 18 - lead by Brendon
# ['Brendon', 'Presley', 'Sienna']
# Group 19 - lead by Chandler
# ['Chandler', 'Dorothy', 'Frederick']
# Group 20 - lead by Tyson
# ['Tyson', 'Blaine', 'Gwen']
# Group 21 - lead by Lena
# ['Lena', 'Jaheim', 'Miriam']
# Group 22 - lead by Shawn
# ['Shawn', 'Heaven', 'Tristan']
# Group 23 - lead by Braylon
# ['Braylon', 'Ezekiel', 'Raul']
# Group 24 - lead by Laurel
# ['Laurel', 'Kayden', 'Donovan']
# Group 25 - lead by Keenan
# ['Keenan', 'Ruby', 'Delilah']
# Group 26 - lead by Frances
# ['Frances', 'Makayla', 'Debora']
# Group 27 - lead by Wade
# ['Wade', 'Esperanza', 'Keira']
# Group 28 - lead by Quinn
# ['Quinn', 'Kaitlin', 'Franklin']
# Group 29 - lead by Karl
# ['Karl', 'Daquan', 'Kawena']
# Group 30 - lead by Mandy
# ['Mandy', 'Jaxon', 'Hazel']
# Group 31 - lead by Bill
# ['Bill', 'Allie', 'Frank']
# Group 32 - lead by Kade
# ['Kade', 'Elliot', 'Mitchell']
# Group 33 - lead by Brooklynn
# ['Brooklynn', 'Karen', 'Boyd']
# Group 34 - lead by Ellie
# ['Ellie', 'Delaney', 'Jaylon']
# Group 35 - lead by Ty
# ['Ty', 'Esperanza', 'Stephon']
# Group 36 - lead by Antwan
# ['Antwan', 'Kekoa', 'Bella']
# Group 37 - lead by Willa
# ['Willa', 'Angelica', 'Candice']
# Group 38 - lead by Floyd
# ['Floyd', 'Lisa', 'Kadence']
# Group 39 - lead by Alvin
# ['Alvin', 'Jean', 'Ann']
# Group 40 - lead by Cristian
# ['Cristian', 'Malcolm', 'Brett']
# Group 41 - lead by Tamika
# ['Tamika', 'Donnie', 'Blaze']
# Group 42 - lead by Cheryl
# ['Cheryl', 'Bronson', 'Louis']
# Group 43 - lead by Elliot
# ['Elliot', 'Jaelyn', 'Kim']
# Group 44 - lead by Jacoby
# ['Jacoby', 'Jaelyn', 'Rodney']
# Group 45 - lead by Spencer
# ['Spencer', 'Dane', 'Tyler']
# Group 46 - lead by Timmy
# ['Timmy', 'James', 'Sabrina']
# Group 47 - lead by Kanani
# ['Kanani', 'Aniyah', 'Jimmie']
# Group 48 - lead by Ivy
# ['Ivy', 'Chelsie', 'Katharine']
# Group 49 - lead by Janay
# ['Janay', 'Alyson', 'Liana']
# Group 50 - lead by Chantelle
# ['Chantelle', 'Kailey', 'Pam']
# Group 51 - lead by Katie
# ['Katie', 'Jane', 'Echo']
# Group 52 - lead by Melissa
# ['Melissa', 'Tamika', 'Bronson']
# Group 53 - lead by Santiago
# ['Santiago', 'Audra', 'Grayson']
# Group 54 - lead by Emely
# ['Emely', 'Roy', 'Hunter']
# Group 55 - lead by Lorrie
# ['Lorrie', 'Alicia', 'Allyson']
# Group 56 - lead by Staci
# ['Staci', 'Roderick', 'Belinda']
# Group 57 - lead by Harley
# ['Harley', 'Melinda', 'Marley']
# Group 58 - lead by Lucy
# ['Lucy', 'Tyrell', 'Lynne']
# Group 59 - lead by Shelbi
# ['Shelbi', 'Gerald', 'Justice']
