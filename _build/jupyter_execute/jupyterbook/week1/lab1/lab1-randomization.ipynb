# %% [markdown]
# # Lab 1: Commenting Code 🧪🖥
#
# As an engineer, it is important to not only be able to write code, but also to read and understand code written by others. One way to improve your understanding of someone else's code is by adding comments to the code.
#
# Comments are lines of code that are not executed by the computer, but are included to explain what is happening in the code. They can be extremely helpful for anyone reading the code, including yourself, to understand (or remember) the logic and purpose behind each line of code. In Python, any line starting with `#` is a comment. For example, the following line of code has a comment above it explaining what the code does:
#
# ```python
# # store the value 3 in a variable called x
# x = 3
# ```
#
# In this lab assignment, you are given some code to read through, and your task will be to add comments to the code to explain what is happening. Don't worry if the code appears complicated and beyond your current understanding. This is intentional, challenge activities are the best way to learn.
#
# To help you should make use of the Python documentation (https://docs.python.org/3/) as you explore and learn the Python syntax. Most documentation for Python code is hosted online.
#
# The code assigns weekly project groups from a spreadsheet of student names. The code has been split into sections with headers summarizing the code in each cell. You should comment every single line since every single line matters to the computer. Some comments have been provided to you to get you started.
#
# By the end of this assignment, you should have a better understanding of how to read and understand code, as well as how to effectively use comments to explain your code. Good luck!

# %% [markdown]
# ## Import Libraries

# %%
# import the scientific computing library numpy and give it the nickname np
import numpy as np
import random
import csv

# %% [markdown]
# ## Define Student class

# %%
# create a python class called Student
class Student:

    # create a constructor for the Student class that has arguments: leader, partners, and name
    def __init__(self, leader, partners, name):
        # store the name in a data member called self.name
        self.name = name
        self.leader = leader
        self.partners = partners

    # create a method called _leader
    def _leader(self):
        # increment the value of self.leader by 1
        self.leader += 1

# %% [markdown]
# ## Define Group class

# %%
class Groups:
    def __init__(self, group_number, group_size, group_members, group_leader):
        self.group_number = group_number
        self.group_size = group_size
        self.group_member = group_members
        self.group_leader = group_leader

# %% [markdown]
# ## Week class

# %%
class Week:
    def __init__(self, week_number, groups):
        self.week_number = week_number
        self.groups = groups

# %% [markdown]
# ## Load and parse the spreadsheet of filenames

# %%
path = './baby-names-by-state.csv'
# open the file at the specified path for reading and give it the name f
with open(path, 'r') as f:
    # create a csv reader object to read the comma-separated file
    reader = csv.reader(f, delimiter=',')
    headers = next(reader)
    data = np.array(list(reader))

names_ = np.unique(data[:, 2])

# %% [markdown]
# ## Assign the groups

# %%
num_students = 177

num_of_weeks = 5

group_size = 3

# Sets the names for the students
# Names were taken from the list of most common names
names = random.choices(names_, k=num_students)

student_list = []

for name in names:
    student_list.append(Student(0, [], name))

num_groups = len(student_list)//group_size

groups_sizes = []

# If the number of students can be evenly split into groups
if len(student_list) % num_groups == 0:

    group_sizes = [group_size] * num_groups

elif len(student_list) % num_groups <= group_size * .8:
    group_sizes = [group_size] * (num_groups - (len(student_list) % num_groups)) + [
        group_size + 1] * (len(student_list) % num_groups)

week_list = []

for week in range(num_of_weeks):

    leader_number = [student.leader for student in student_list]

    leader_value = sorted(leader_number)[:len(group_sizes)]

    def select_leader(leader_options):
        return np.random.choice(leader_options)

    grouped_students = []
    group_list = []

    for i, _leader_value in enumerate(leader_value):

        leader_number = [student.leader for student in student_list]

        leader_options = np.argwhere(
            np.array(leader_number) == _leader_value).squeeze()

        leader_ = select_leader(leader_options)

        while leader_ in grouped_students:
            leader_ = select_leader(leader_options)

        group_list.append(Groups(i+1,
                                 group_sizes[i],
                                 [student_list[leader_]],
                                 [student_list[leader_]]))

        student_list[leader_]._leader()

        grouped_students.append(leader_)

    for i, group in enumerate(group_list):
        for j in range(group.group_size-1):
            remaining_students = set(
                np.arange(len(student_list)))-set(grouped_students)

            student_num_ = np.random.choice(list(remaining_students))

            group.group_member.append(student_list[student_num_])

            grouped_students.append(student_num_)

    week_list.append(Week(week + 1, group_list))

# %% [markdown]
# ## Print out the groups

# %%
for week in week_list:
    print(f'Week {week.week_number}\n')

    for group in week.groups:
        print(
            f'Group {group.group_number} - lead by {group.group_leader[0].name}')
        print([i.name for i in group.group_member])

    print('\n')
# Out:
# Week 1
#
# Group 1 - lead by Alina
# ['Alina', 'Nadia', 'Jackson']
# Group 2 - lead by Dana
# ['Dana', 'Mackenzie', 'Milton']
# Group 3 - lead by Tiara
# ['Tiara', 'Tehani', 'Jacoby']
# Group 4 - lead by Mikayla
# ['Mikayla', 'George', 'Katina']
# Group 5 - lead by Summer
# ['Summer', 'Aidan', 'Caitlyn']
# Group 6 - lead by Carter
# ['Carter', 'Holden', 'Kara']
# Group 7 - lead by Mercedes
# ['Mercedes', 'Wassillie', 'Kayleigh']
# Group 8 - lead by Geoffrey
# ['Geoffrey', 'Byron', 'Shaun']
# Group 9 - lead by Edna
# ['Edna', 'Eleanor', 'Nicholas']
# Group 10 - lead by Kobe
# ['Kobe', 'Maile', 'Kiara']
# Group 11 - lead by Kiani
# ['Kiani', 'Belinda', 'Don']
# Group 12 - lead by Ira
# ['Ira', 'Babygirl', 'Harper']
# Group 13 - lead by Carissa
# ['Carissa', 'George', 'Addison']
# Group 14 - lead by Greg
# ['Greg', 'Dominic', 'Jose']
# Group 15 - lead by Andre
# ['Andre', 'Justice', 'Brenda']
# Group 16 - lead by Isabella
# ['Isabella', 'Marcos', 'Amaya']
# Group 17 - lead by Gerard
# ['Gerard', 'Alissa', 'Bobby']
# Group 18 - lead by Amelia
# ['Amelia', 'Liza', 'Georgia']
# Group 19 - lead by Oscar
# ['Oscar', 'Ladarius', 'Jeanette']
# Group 20 - lead by Samantha
# ['Samantha', 'Jaxon', 'Aaron']
# Group 21 - lead by Jose
# ['Jose', 'Kari', 'Maddox']
# Group 22 - lead by Ryder
# ['Ryder', 'Ruth', 'Kenny']
# Group 23 - lead by Ted
# ['Ted', 'Melanie', 'Tommy']
# Group 24 - lead by Anita
# ['Anita', 'Leon', 'Anya']
# Group 25 - lead by Bryant
# ['Bryant', 'Chelsey', 'Alisha']
# Group 26 - lead by Janelle
# ['Janelle', 'Angelique', 'Sherrie']
# Group 27 - lead by Jasmine
# ['Jasmine', 'Toby', 'Brandy']
# Group 28 - lead by Jenifer
# ['Jenifer', 'Lexie', 'Leilani']
# Group 29 - lead by Carmen
# ['Carmen', 'Chantel', 'Katherine']
# Group 30 - lead by Edwin
# ['Edwin', 'Scotty', 'Halle']
# Group 31 - lead by Lloyd
# ['Lloyd', 'Annette', 'Lila']
# Group 32 - lead by Marlon
# ['Marlon', 'Justine', 'Colby']
# Group 33 - lead by Myra
# ['Myra', 'Destinee', 'Carly']
# Group 34 - lead by Blaine
# ['Blaine', 'Breanna', 'Keanu']
# Group 35 - lead by Rachael
# ['Rachael', 'Ayden', 'Jaclyn']
# Group 36 - lead by Charity
# ['Charity', 'Martin', 'Barbara']
# Group 37 - lead by Glenn
# ['Glenn', 'Jaclyn', 'Harrison']
# Group 38 - lead by Kiana
# ['Kiana', 'Vernon', 'Marcy']
# Group 39 - lead by Jordyn
# ['Jordyn', 'Roy', 'Pam']
# Group 40 - lead by Bryanna
# ['Bryanna', 'Caroline', 'Kendra']
# Group 41 - lead by Hailey
# ['Hailey', 'Emely', 'Brooklyn']
# Group 42 - lead by Guadalupe
# ['Guadalupe', 'Addisyn', 'Arianna']
# Group 43 - lead by Tiara
# ['Tiara', 'Carrie', 'Camryn']
# Group 44 - lead by Robin
# ['Robin', 'Theodore', 'Ciara']
# Group 45 - lead by Brady
# ['Brady', 'Emerson', 'Joe']
# Group 46 - lead by Charmaine
# ['Charmaine', 'Julian', 'Tracie']
# Group 47 - lead by Amira
# ['Amira', 'Colby', 'Nikki']
# Group 48 - lead by Aiden
# ['Aiden', 'Kimberley', 'Brynn']
# Group 49 - lead by Vivian
# ['Vivian', 'Ruben', 'Neil']
# Group 50 - lead by Hadley
# ['Hadley', 'Shaylee', 'Annette']
# Group 51 - lead by Randall
# ['Randall', 'Mikaela', 'Graham']
# Group 52 - lead by Renae
# ['Renae', 'Theresa', 'Gwen']
# Group 53 - lead by Pedro
# ['Pedro', 'Jody', 'Trenton']
# Group 54 - lead by Annabelle
# ['Annabelle', 'Talon', 'Nichole']
# Group 55 - lead by Dakota
# ['Dakota', 'Kamalei', 'Misty']
# Group 56 - lead by Elaina
# ['Elaina', 'Malachi', 'Javier']
# Group 57 - lead by Khadijah
# ['Khadijah', 'Elijah', 'Ashanti']
# Group 58 - lead by Francine
# ['Francine', 'Aiden', 'Jay']
# Group 59 - lead by Bridger
# ['Bridger', 'Janiya', 'Dallin']
#
#
# Week 2
#
# Group 1 - lead by Chantel
# ['Chantel', 'Janelle', 'Arianna']
# Group 2 - lead by Kara
# ['Kara', 'Guadalupe', 'Andre']
# Group 3 - lead by George
# ['George', 'Ruth', 'Marcy']
# Group 4 - lead by Nicholas
# ['Nicholas', 'Tiara', 'Leon']
# Group 5 - lead by Babygirl
# ['Babygirl', 'Malachi', 'Mikaela']
# Group 6 - lead by Jaclyn
# ['Jaclyn', 'Janiya', 'Bryanna']
# Group 7 - lead by Kenny
# ['Kenny', 'Ciara', 'Jasmine']
# Group 8 - lead by Lexie
# ['Lexie', 'Kimberley', 'Kiana']
# Group 9 - lead by Nadia
# ['Nadia', 'Kobe', 'Shaylee']
# Group 10 - lead by Shaun
# ['Shaun', 'Carly', 'Kari']
# Group 11 - lead by Tommy
# ['Tommy', 'Addison', 'Annabelle']
# Group 12 - lead by Talon
# ['Talon', 'Kamalei', 'Anya']
# Group 13 - lead by Gwen
# ['Gwen', 'Scotty', 'Hadley']
# Group 14 - lead by Javier
# ['Javier', 'Glenn', 'Dana']
# Group 15 - lead by Harrison
# ['Harrison', 'Carter', 'Aidan']
# Group 16 - lead by Ladarius
# ['Ladarius', 'Jay', 'Mercedes']
# Group 17 - lead by Lila
# ['Lila', 'Brenda', 'Jackson']
# Group 18 - lead by Katina
# ['Katina', 'Leilani', 'Jose']
# Group 19 - lead by Nikki
# ['Nikki', 'Gerard', 'Charmaine']
# Group 20 - lead by Toby
# ['Toby', 'Liza', 'Alina']
# Group 21 - lead by Caroline
# ['Caroline', 'Dallin', 'Trenton']
# Group 22 - lead by Addisyn
# ['Addisyn', 'Graham', 'Mikayla']
# Group 23 - lead by Joe
# ['Joe', 'Elaina', 'Brynn']
# Group 24 - lead by Caitlyn
# ['Caitlyn', 'Hailey', 'Jaxon']
# Group 25 - lead by Neil
# ['Neil', 'Renae', 'Randall']
# Group 26 - lead by Emely
# ['Emely', 'Misty', 'Justice']
# Group 27 - lead by Ruben
# ['Ruben', 'Ryder', 'Kiani']
# Group 28 - lead by Eleanor
# ['Eleanor', 'Isabella', 'Edna']
# Group 29 - lead by Maddox
# ['Maddox', 'Ayden', 'Angelique']
# Group 30 - lead by Mackenzie
# ['Mackenzie', 'Camryn', 'Charity']
# Group 31 - lead by Carrie
# ['Carrie', 'Blaine', 'Holden']
# Group 32 - lead by Ashanti
# ['Ashanti', 'Tiara', 'Melanie']
# Group 33 - lead by Jody
# ['Jody', 'Amelia', 'Georgia']
# Group 34 - lead by Roy
# ['Roy', 'Summer', 'Maile']
# Group 35 - lead by Aiden
# ['Aiden', 'Rachael', 'Chelsey']
# Group 36 - lead by Alissa
# ['Alissa', 'Theodore', 'Marlon']
# Group 37 - lead by Theresa
# ['Theresa', 'Colby', 'Jaclyn']
# Group 38 - lead by Milton
# ['Milton', 'Edwin', 'Amira']
# Group 39 - lead by Alisha
# ['Alisha', 'Robin', 'Annette']
# Group 40 - lead by Pam
# ['Pam', 'Belinda', 'George']
# Group 41 - lead by Elijah
# ['Elijah', 'Dominic', 'Byron']
# Group 42 - lead by Destinee
# ['Destinee', 'Keanu', 'Ira']
# Group 43 - lead by Nichole
# ['Nichole', 'Lloyd', 'Martin']
# Group 44 - lead by Emerson
# ['Emerson', 'Myra', 'Aaron']
# Group 45 - lead by Justine
# ['Justine', 'Vivian', 'Colby']
# Group 46 - lead by Katherine
# ['Katherine', 'Vernon', 'Aiden']
# Group 47 - lead by Barbara
# ['Barbara', 'Samantha', 'Annette']
# Group 48 - lead by Halle
# ['Halle', 'Julian', 'Bryant']
# Group 49 - lead by Breanna
# ['Breanna', 'Khadijah', 'Anita']
# Group 50 - lead by Tehani
# ['Tehani', 'Brady', 'Harper']
# Group 51 - lead by Kiara
# ['Kiara', 'Jose', 'Kendra']
# Group 52 - lead by Sherrie
# ['Sherrie', 'Bobby', 'Francine']
# Group 53 - lead by Jeanette
# ['Jeanette', 'Carmen', 'Greg']
# Group 54 - lead by Kayleigh
# ['Kayleigh', 'Oscar', 'Jenifer']
# Group 55 - lead by Brandy
# ['Brandy', 'Jordyn', 'Dakota']
# Group 56 - lead by Jacoby
# ['Jacoby', 'Brooklyn', 'Ted']
# Group 57 - lead by Don
# ['Don', 'Geoffrey', 'Tracie']
# Group 58 - lead by Marcos
# ['Marcos', 'Amaya', 'Bridger']
# Group 59 - lead by Wassillie
# ['Wassillie', 'Pedro', 'Carissa']
#
#
# Week 3
#
# Group 1 - lead by Melanie
# ['Melanie', 'Joe', 'Carmen']
# Group 2 - lead by Trenton
# ['Trenton', 'Charity', 'Talon']
# Group 3 - lead by Misty
# ['Misty', 'Carissa', 'Nadia']
# Group 4 - lead by Harper
# ['Harper', 'Mercedes', 'Jordyn']
# Group 5 - lead by Jay
# ['Jay', 'Ted', 'Javier']
# Group 6 - lead by Kari
# ['Kari', 'Jaclyn', 'Alissa']
# Group 7 - lead by Justice
# ['Justice', 'Ruben', 'Kiana']
# Group 8 - lead by Colby
# ['Colby', 'Bryanna', 'Anita']
# Group 9 - lead by Camryn
# ['Camryn', 'Chantel', 'Lloyd']
# Group 10 - lead by Belinda
# ['Belinda', 'Dana', 'Oscar']
# Group 11 - lead by Maile
# ['Maile', 'Aiden', 'Charmaine']
# Group 12 - lead by Graham
# ['Graham', 'Bryant', 'Robin']
# Group 13 - lead by Bobby
# ['Bobby', 'Jenifer', 'Don']
# Group 14 - lead by Ruth
# ['Ruth', 'Tiara', 'Kobe']
# Group 15 - lead by Ayden
# ['Ayden', 'Jose', 'Ashanti']
# Group 16 - lead by Anya
# ['Anya', 'Marlon', 'George']
# Group 17 - lead by Brenda
# ['Brenda', 'Barbara', 'Summer']
# Group 18 - lead by Brooklyn
# ['Brooklyn', 'Pam', 'Alina']
# Group 19 - lead by Jackson
# ['Jackson', 'Vivian', 'Caitlyn']
# Group 20 - lead by Vernon
# ['Vernon', 'Elijah', 'Tehani']
# Group 21 - lead by Kimberley
# ['Kimberley', 'Renae', 'Blaine']
# Group 22 - lead by Kendra
# ['Kendra', 'Jacoby', 'Dakota']
# Group 23 - lead by Keanu
# ['Keanu', 'Tommy', 'Tiara']
# Group 24 - lead by Angelique
# ['Angelique', 'Carrie', 'Emely']
# Group 25 - lead by Leilani
# ['Leilani', 'Jody', 'Glenn']
# Group 26 - lead by Malachi
# ['Malachi', 'Annabelle', 'Maddox']
# Group 27 - lead by Dominic
# ['Dominic', 'Andre', 'Francine']
# Group 28 - lead by Arianna
# ['Arianna', 'Pedro', 'Babygirl']
# Group 29 - lead by Janiya
# ['Janiya', 'Myra', 'Khadijah']
# Group 30 - lead by Brynn
# ['Brynn', 'Hailey', 'Edwin']
# Group 31 - lead by Martin
# ['Martin', 'Mikayla', 'Eleanor']
# Group 32 - lead by Aaron
# ['Aaron', 'Geoffrey', 'Carter']
# Group 33 - lead by Chelsey
# ['Chelsey', 'Theresa', 'Nicholas']
# Group 34 - lead by Shaylee
# ['Shaylee', 'Harrison', 'Guadalupe']
# Group 35 - lead by Dallin
# ['Dallin', 'Bridger', 'Hadley']
# Group 36 - lead by George
# ['George', 'Rachael', 'Sherrie']
# Group 37 - lead by Colby
# ['Colby', 'Addisyn', 'Mackenzie']
# Group 38 - lead by Jaclyn
# ['Jaclyn', 'Ryder', 'Emerson']
# Group 39 - lead by Ciara
# ['Ciara', 'Elaina', 'Destinee']
# Group 40 - lead by Liza
# ['Liza', 'Janelle', 'Aiden']
# Group 41 - lead by Annette
# ['Annette', 'Gwen', 'Shaun']
# Group 42 - lead by Byron
# ['Byron', 'Roy', 'Ira']
# Group 43 - lead by Holden
# ['Holden', 'Kara', 'Kiani']
# Group 44 - lead by Amaya
# ['Amaya', 'Jeanette', 'Kiara']
# Group 45 - lead by Addison
# ['Addison', 'Gerard', 'Edna']
# Group 46 - lead by Aidan
# ['Aidan', 'Lila', 'Georgia']
# Group 47 - lead by Tracie
# ['Tracie', 'Samantha', 'Isabella']
# Group 48 - lead by Carly
# ['Carly', 'Caroline', 'Brady']
# Group 49 - lead by Julian
# ['Julian', 'Wassillie', 'Jasmine']
# Group 50 - lead by Mikaela
# ['Mikaela', 'Kenny', 'Katina']
# Group 51 - lead by Marcy
# ['Marcy', 'Breanna', 'Amira']
# Group 52 - lead by Jose
# ['Jose', 'Kayleigh', 'Amelia']
# Group 53 - lead by Theodore
# ['Theodore', 'Justine', 'Halle']
# Group 54 - lead by Kamalei
# ['Kamalei', 'Lexie', 'Marcos']
# Group 55 - lead by Scotty
# ['Scotty', 'Nichole', 'Katherine']
# Group 56 - lead by Annette
# ['Annette', 'Milton', 'Nikki']
# Group 57 - lead by Leon
# ['Leon', 'Alisha', 'Neil']
# Group 58 - lead by Jaxon
# ['Jaxon', 'Ladarius', 'Toby']
# Group 59 - lead by Greg
# ['Greg', 'Randall', 'Brandy']
#
#
# Week 4
#
# Group 1 - lead by Tiara
# ['Tiara', 'Alissa', 'Joe']
# Group 2 - lead by Carly
# ['Carly', 'Malachi', 'Katina']
# Group 3 - lead by Aiden
# ['Aiden', 'Edna', 'Julian']
# Group 4 - lead by Nicholas
# ['Nicholas', 'Andre', 'Kiara']
# Group 5 - lead by Graham
# ['Graham', 'Janelle', 'Edwin']
# Group 6 - lead by Theresa
# ['Theresa', 'Pam', 'Myra']
# Group 7 - lead by Dana
# ['Dana', 'Renae', 'Vernon']
# Group 8 - lead by Ashanti
# ['Ashanti', 'Amaya', 'Destinee']
# Group 9 - lead by Carmen
# ['Carmen', 'Addisyn', 'Mackenzie']
# Group 10 - lead by Marlon
# ['Marlon', 'Roy', 'Belinda']
# Group 11 - lead by Dominic
# ['Dominic', 'Kimberley', 'Tommy']
# Group 12 - lead by Kayleigh
# ['Kayleigh', 'Shaun', 'Elijah']
# Group 13 - lead by Lila
# ['Lila', 'Jose', 'Jody']
# Group 14 - lead by Ruth
# ['Ruth', 'Ciara', 'Bryanna']
# Group 15 - lead by Liza
# ['Liza', 'Ira', 'Janiya']
# Group 16 - lead by Mikayla
# ['Mikayla', 'Shaylee', 'Justice']
# Group 17 - lead by Chelsey
# ['Chelsey', 'Khadijah', 'Dallin']
# Group 18 - lead by Lloyd
# ['Lloyd', 'Aiden', 'Carrie']
# Group 19 - lead by Don
# ['Don', 'Gerard', 'Charity']
# Group 20 - lead by Ryder
# ['Ryder', 'Milton', 'Amira']
# Group 21 - lead by Javier
# ['Javier', 'George', 'Aidan']
# Group 22 - lead by Scotty
# ['Scotty', 'Anya', 'Caitlyn']
# Group 23 - lead by Vivian
# ['Vivian', 'Byron', 'Maddox']
# Group 24 - lead by Angelique
# ['Angelique', 'Mikaela', 'Colby']
# Group 25 - lead by Tiara
# ['Tiara', 'Arianna', 'Marcy']
# Group 26 - lead by Kendra
# ['Kendra', 'Kari', 'Marcos']
# Group 27 - lead by Melanie
# ['Melanie', 'Wassillie', 'Colby']
# Group 28 - lead by Pedro
# ['Pedro', 'Ladarius', 'Katherine']
# Group 29 - lead by Breanna
# ['Breanna', 'Hailey', 'Sherrie']
# Group 30 - lead by Hadley
# ['Hadley', 'Alisha', 'Carter']
# Group 31 - lead by Neil
# ['Neil', 'Annette', 'Anita']
# Group 32 - lead by Emely
# ['Emely', 'Trenton', 'Camryn']
# Group 33 - lead by Ayden
# ['Ayden', 'Ted', 'Nikki']
# Group 34 - lead by Carissa
# ['Carissa', 'Isabella', 'Justine']
# Group 35 - lead by Harrison
# ['Harrison', 'Jackson', 'Glenn']
# Group 36 - lead by Tracie
# ['Tracie', 'Kiani', 'Dakota']
# Group 37 - lead by Robin
# ['Robin', 'Nichole', 'Jaclyn']
# Group 38 - lead by Kamalei
# ['Kamalei', 'Maile', 'Blaine']
# Group 39 - lead by Ruben
# ['Ruben', 'Bryant', 'Kiana']
# Group 40 - lead by Brynn
# ['Brynn', 'Summer', 'Annette']
# Group 41 - lead by Keanu
# ['Keanu', 'Kenny', 'Emerson']
# Group 42 - lead by Charmaine
# ['Charmaine', 'Jordyn', 'Mercedes']
# Group 43 - lead by Jasmine
# ['Jasmine', 'Brandy', 'Martin']
# Group 44 - lead by Jaclyn
# ['Jaclyn', 'Leon', 'Jay']
# Group 45 - lead by Samantha
# ['Samantha', 'Brenda', 'Tehani']
# Group 46 - lead by Barbara
# ['Barbara', 'Nadia', 'Eleanor']
# Group 47 - lead by Kobe
# ['Kobe', 'Elaina', 'Georgia']
# Group 48 - lead by Caroline
# ['Caroline', 'Amelia', 'Gwen']
# Group 49 - lead by Halle
# ['Halle', 'Harper', 'Randall']
# Group 50 - lead by Bridger
# ['Bridger', 'George', 'Lexie']
# Group 51 - lead by Holden
# ['Holden', 'Toby', 'Francine']
# Group 52 - lead by Guadalupe
# ['Guadalupe', 'Greg', 'Geoffrey']
# Group 53 - lead by Jenifer
# ['Jenifer', 'Jeanette', 'Brady']
# Group 54 - lead by Aaron
# ['Aaron', 'Misty', 'Leilani']
# Group 55 - lead by Jacoby
# ['Jacoby', 'Oscar', 'Babygirl']
# Group 56 - lead by Alina
# ['Alina', 'Bobby', 'Addison']
# Group 57 - lead by Rachael
# ['Rachael', 'Brooklyn', 'Jose']
# Group 58 - lead by Theodore
# ['Theodore', 'Annabelle', 'Talon']
# Group 59 - lead by Chantel
# ['Chantel', 'Kara', 'Jaxon']
#
#
# Week 5
#
# Group 1 - lead by Vernon
# ['Vernon', 'Nicholas', 'Greg']
# Group 2 - lead by Amaya
# ['Amaya', 'Bridger', 'Carmen']
# Group 3 - lead by Misty
# ['Misty', 'Aiden', 'Annabelle']
# Group 4 - lead by Wassillie
# ['Wassillie', 'Tiara', 'Nikki']
# Group 5 - lead by George
# ['George', 'Chantel', 'Myra']
# Group 6 - lead by Eleanor
# ['Eleanor', 'Jaclyn', 'Khadijah']
# Group 7 - lead by Jose
# ['Jose', 'Kayleigh', 'Marlon']
# Group 8 - lead by Tehani
# ['Tehani', 'Amira', 'Tiara']
# Group 9 - lead by Colby
# ['Colby', 'Shaun', 'Carissa']
# Group 10 - lead by Ira
# ['Ira', 'Charity', 'Robin']
# Group 11 - lead by Kara
# ['Kara', 'Jenifer', 'Chelsey']
# Group 12 - lead by Elaina
# ['Elaina', 'Harrison', 'Summer']
# Group 13 - lead by Mercedes
# ['Mercedes', 'Jody', 'Jasmine']
# Group 14 - lead by Addisyn
# ['Addisyn', 'Halle', 'Angelique']
# Group 15 - lead by Anya
# ['Anya', 'Lexie', 'Graham']
# Group 16 - lead by Glenn
# ['Glenn', 'Hailey', 'Aidan']
# Group 17 - lead by Camryn
# ['Camryn', 'Martin', 'Sherrie']
# Group 18 - lead by Bobby
# ['Bobby', 'Ruth', 'Gwen']
# Group 19 - lead by Anita
# ['Anita', 'Theresa', 'Babygirl']
# Group 20 - lead by Brandy
# ['Brandy', 'Geoffrey', 'Pedro']
# Group 21 - lead by Jose
# ['Jose', 'Samantha', 'Rachael']
# Group 22 - lead by Dakota
# ['Dakota', 'Justine', 'Scotty']
# Group 23 - lead by Julian
# ['Julian', 'Holden', 'Alina']
# Group 24 - lead by Destinee
# ['Destinee', 'Lila', 'Jackson']
# Group 25 - lead by Addison
# ['Addison', 'Annette', 'Ciara']
# Group 26 - lead by Talon
# ['Talon', 'Barbara', 'Caitlyn']
# Group 27 - lead by Jordyn
# ['Jordyn', 'Justice', 'Neil']
# Group 28 - lead by Marcy
# ['Marcy', 'Hadley', 'Carter']
# Group 29 - lead by Bryanna
# ['Bryanna', 'Alissa', 'Vivian']
# Group 30 - lead by Mikaela
# ['Mikaela', 'Leon', 'Aiden']
# Group 31 - lead by Kari
# ['Kari', 'Katherine', 'Kamalei']
# Group 32 - lead by Edwin
# ['Edwin', 'Mackenzie', 'Jaclyn']
# Group 33 - lead by Gerard
# ['Gerard', 'Brady', 'Francine']
# Group 34 - lead by Byron
# ['Byron', 'Guadalupe', 'Joe']
# Group 35 - lead by Kenny
# ['Kenny', 'Carrie', 'Emely']
# Group 36 - lead by Bryant
# ['Bryant', 'Charmaine', 'Breanna']
# Group 37 - lead by Janiya
# ['Janiya', 'Ryder', 'Javier']
# Group 38 - lead by Arianna
# ['Arianna', 'Ruben', 'Katina']
# Group 39 - lead by Trenton
# ['Trenton', 'Leilani', 'Andre']
# Group 40 - lead by Kiana
# ['Kiana', 'Dana', 'Kiara']
# Group 41 - lead by Malachi
# ['Malachi', 'Maile', 'Milton']
# Group 42 - lead by Isabella
# ['Isabella', 'Jeanette', 'Nichole']
# Group 43 - lead by Brooklyn
# ['Brooklyn', 'Ayden', 'Jaxon']
# Group 44 - lead by Annette
# ['Annette', 'Theodore', 'Aaron']
# Group 45 - lead by Alisha
# ['Alisha', 'Tommy', 'Shaylee']
# Group 46 - lead by Ladarius
# ['Ladarius', 'Tracie', 'Kendra']
# Group 47 - lead by Belinda
# ['Belinda', 'Janelle', 'Keanu']
# Group 48 - lead by George
# ['George', 'Emerson', 'Dallin']
# Group 49 - lead by Toby
# ['Toby', 'Harper', 'Jay']
# Group 50 - lead by Amelia
# ['Amelia', 'Colby', 'Caroline']
# Group 51 - lead by Ted
# ['Ted', 'Jacoby', 'Maddox']
# Group 52 - lead by Marcos
# ['Marcos', 'Brynn', 'Elijah']
# Group 53 - lead by Brenda
# ['Brenda', 'Don', 'Mikayla']
# Group 54 - lead by Edna
# ['Edna', 'Roy', 'Liza']
# Group 55 - lead by Kimberley
# ['Kimberley', 'Carly', 'Dominic']
# Group 56 - lead by Randall
# ['Randall', 'Pam', 'Blaine']
# Group 57 - lead by Nadia
# ['Nadia', 'Renae', 'Melanie']
# Group 58 - lead by Oscar
# ['Oscar', 'Kobe', 'Georgia']
# Group 59 - lead by Kiani
# ['Kiani', 'Ashanti', 'Lloyd']
