# %% [markdown]
# # Lab 1: Commenting Code 🧪🖥
#
# As an engineer, it is important to not only be able to write code, but also to read and understand code written by others. One way to improve your understanding of someone else's code is by adding comments to the code.
#
# Comments are lines of code that are not executed by the computer, but are included to explain what is happening in the code. They can be extremely helpful for anyone reading the code, including yourself, to understand (or remember) the logic and purpose behind each line of code. In Python, any line starting with `#` is a comment. For example, the following line of code has a comment above it explaining what the code does:
#
# ```python
# # store the value 3 in a variable called x
# x = 3
# ```
#
# In this lab assignment, you are given some code to read through, and your task will be to add comments to the code to explain what is happening. Don't worry if the code appears complicated and beyond your current understanding. This is intentional, challenge activities are the best way to learn.
#
# To help you should make use of the Python documentation (https://docs.python.org/3/) as you explore and learn the Python syntax. Most documentation for Python code is hosted online.
#
# The code assigns weekly project groups from a spreadsheet of student names. The code has been split into sections with headers summarizing the code in each cell. You should comment every single line since every single line matters to the computer. Some comments have been provided to you to get you started.
#
# By the end of this assignment, you should have a better understanding of how to read and understand code, as well as how to effectively use comments to explain your code. Good luck!

# %% [markdown]
# ## Import Libraries

# %%
# import the scientific computing library numpy and give it the nickname np
import numpy as np
import random
import csv

# %% [markdown]
# ## Define Student class

# %%
# create a python class called Student
class Student:

    # create a constructor for the Student class that has arguments: leader, partners, and name
    def __init__(self, leader, partners, name):
        # store the name in a data member called self.name
        self.name = name
        self.leader = leader
        self.partners = partners

    # create a method called _leader
    def _leader(self):
        # increment the value of self.leader by 1
        self.leader += 1

# %% [markdown]
# ## Define Group class

# %%
class Groups:
    def __init__(self, group_number, group_size, group_members, group_leader):
        self.group_number = group_number
        self.group_size = group_size
        self.group_member = group_members
        self.group_leader = group_leader

# %% [markdown]
# ## Week class

# %%
class Week:
    def __init__(self, week_number, groups):
        self.week_number = week_number
        self.groups = groups

# %% [markdown]
# ## Load and parse the spreadsheet of filenames

# %%
path = './baby-names-by-state.csv'
# open the file at the specified path for reading and give it the name f
with open(path, 'r') as f:
    # create a csv reader object to read the comma-separated file
    reader = csv.reader(f, delimiter=',')
    headers = next(reader)
    data = np.array(list(reader))

names_ = np.unique(data[:, 2])

# %% [markdown]
# ## Assign the groups

# %%
num_students = 177

num_of_weeks = 5

group_size = 3

# Sets the names for the students
# Names were taken from the list of most common names
names = random.choices(names_, k=num_students)

student_list = []

for name in names:
    student_list.append(Student(0, [], name))

num_groups = len(student_list)//group_size

groups_sizes = []

# If the number of students can be evenly split into groups
if len(student_list) % num_groups == 0:

    group_sizes = [group_size] * num_groups

elif len(student_list) % num_groups <= group_size * .8:
    group_sizes = [group_size] * (num_groups - (len(student_list) % num_groups)) + [
        group_size + 1] * (len(student_list) % num_groups)

week_list = []

for week in range(num_of_weeks):

    leader_number = [student.leader for student in student_list]

    leader_value = sorted(leader_number)[:len(group_sizes)]

    def select_leader(leader_options):
        return np.random.choice(leader_options)

    grouped_students = []
    group_list = []

    for i, _leader_value in enumerate(leader_value):

        leader_number = [student.leader for student in student_list]

        leader_options = np.argwhere(
            np.array(leader_number) == _leader_value).squeeze()

        leader_ = select_leader(leader_options)

        while leader_ in grouped_students:
            leader_ = select_leader(leader_options)

        group_list.append(Groups(i+1,
                                 group_sizes[i],
                                 [student_list[leader_]],
                                 [student_list[leader_]]))

        student_list[leader_]._leader()

        grouped_students.append(leader_)

    for i, group in enumerate(group_list):
        for j in range(group.group_size-1):
            remaining_students = set(
                np.arange(len(student_list)))-set(grouped_students)

            student_num_ = np.random.choice(list(remaining_students))

            group.group_member.append(student_list[student_num_])

            grouped_students.append(student_num_)

    week_list.append(Week(week + 1, group_list))

# %% [markdown]
# ## Print out the groups

# %%
for week in week_list:
    print(f'Week {week.week_number}\n')

    for group in week.groups:
        print(
            f'Group {group.group_number} - lead by {group.group_leader[0].name}')
        print([i.name for i in group.group_member])

    print('\n')
# Out:
# Week 1
#
# Group 1 - lead by Kristopher
# ['Kristopher', 'Dexter', 'Keoni']
# Group 2 - lead by Deja
# ['Deja', 'Tana', 'Laci']
# Group 3 - lead by Allie
# ['Allie', 'Tori', 'Jimmy']
# Group 4 - lead by Nasir
# ['Nasir', 'Myron', 'Sophia']
# Group 5 - lead by Tyler
# ['Tyler', 'Marie', 'Luis']
# Group 6 - lead by Kaitlin
# ['Kaitlin', 'Marco', 'Jesus']
# Group 7 - lead by Sherri
# ['Sherri', 'Kelley', 'Tristan']
# Group 8 - lead by Leon
# ['Leon', 'Shelbi', 'Brianna']
# Group 9 - lead by Hope
# ['Hope', 'Tracey', 'Keri']
# Group 10 - lead by Kendrick
# ['Kendrick', 'Lynn', 'Georgia']
# Group 11 - lead by Theodore
# ['Theodore', 'Colby', 'Joy']
# Group 12 - lead by Tracey
# ['Tracey', 'Maribel', 'Raegan']
# Group 13 - lead by Jaylon
# ['Jaylon', 'Bryanna', 'Meghan']
# Group 14 - lead by Kainalu
# ['Kainalu', 'Serenity', 'Dwayne']
# Group 15 - lead by Marsha
# ['Marsha', 'Kylie', 'Destiny']
# Group 16 - lead by Miracle
# ['Miracle', 'Wesley', 'Donnie']
# Group 17 - lead by Lori
# ['Lori', 'Tabatha', 'Charlotte']
# Group 18 - lead by Johnathon
# ['Johnathon', 'Chase', 'Jasmine']
# Group 19 - lead by Frances
# ['Frances', 'Barbara', 'Sally']
# Group 20 - lead by Alexa
# ['Alexa', 'Brandie', 'Ciara']
# Group 21 - lead by Ezekiel
# ['Ezekiel', 'Don', 'Dawson']
# Group 22 - lead by Shaquille
# ['Shaquille', 'Chiquita', 'Shawna']
# Group 23 - lead by Cristian
# ['Cristian', 'Gina', 'Sidney']
# Group 24 - lead by Bryanna
# ['Bryanna', 'Justice', 'Makana']
# Group 25 - lead by Chiquita
# ['Chiquita', 'Ethan', 'Sheryl']
# Group 26 - lead by Guadalupe
# ['Guadalupe', 'Henry', 'Chanel']
# Group 27 - lead by Latonya
# ['Latonya', 'Janiya', 'Linda']
# Group 28 - lead by Jamya
# ['Jamya', 'Latasha', 'Branden']
# Group 29 - lead by Samuel
# ['Samuel', 'Brody', 'Kobe']
# Group 30 - lead by David
# ['David', 'Alex', 'Jefferson']
# Group 31 - lead by Jaqueline
# ['Jaqueline', 'Cristina', 'Vicky']
# Group 32 - lead by Claire
# ['Claire', 'Linda', 'Caitlin']
# Group 33 - lead by Sydney
# ['Sydney', 'Sebastian', 'Zayden']
# Group 34 - lead by Kailey
# ['Kailey', 'Dixie', 'Marlon']
# Group 35 - lead by Ayden
# ['Ayden', 'Mckay', 'Danica']
# Group 36 - lead by Myra
# ['Myra', 'Rosie', 'Kainalu']
# Group 37 - lead by Sylvia
# ['Sylvia', 'Craig', 'Craig']
# Group 38 - lead by Gene
# ['Gene', 'Darrell', 'Lani']
# Group 39 - lead by Irma
# ['Irma', 'Donald', 'Marcia']
# Group 40 - lead by Bernard
# ['Bernard', 'Stacie', 'Bryant']
# Group 41 - lead by Destiny
# ['Destiny', 'Andres', 'Kenzie']
# Group 42 - lead by Trevor
# ['Trevor', 'Warren', 'Aiden']
# Group 43 - lead by Raegan
# ['Raegan', 'Sierra', 'Noelani']
# Group 44 - lead by Vicky
# ['Vicky', 'Kylie', 'Mahina']
# Group 45 - lead by Gloria
# ['Gloria', 'Lena', 'Kaitlyn']
# Group 46 - lead by Gabriela
# ['Gabriela', 'Cyrus', 'Eugene']
# Group 47 - lead by Lorenzo
# ['Lorenzo', 'Desiree', 'Tabitha']
# Group 48 - lead by Arielle
# ['Arielle', 'Nia', 'Raekwon']
# Group 49 - lead by Raul
# ['Raul', 'Roderick', 'Sonya']
# Group 50 - lead by Bonnie
# ['Bonnie', 'Bethany', 'Vicky']
# Group 51 - lead by Austin
# ['Austin', 'Cheri', 'Kay']
# Group 52 - lead by Brandy
# ['Brandy', 'Carson', 'Kalani']
# Group 53 - lead by Cristina
# ['Cristina', 'Audra', 'Kris']
# Group 54 - lead by Marion
# ['Marion', 'Orlando', 'Teresa']
# Group 55 - lead by Ramona
# ['Ramona', 'Loriann', 'Charlotte']
# Group 56 - lead by Kainoa
# ['Kainoa', 'Mandy', 'Francis']
# Group 57 - lead by Trinity
# ['Trinity', 'Dana', 'Reagan']
# Group 58 - lead by Misti
# ['Misti', 'Betsy', 'Rick']
# Group 59 - lead by Edward
# ['Edward', 'Janay', 'Agnes']
#
#
# Week 2
#
# Group 1 - lead by Myron
# ['Myron', 'Shawna', 'Roderick']
# Group 2 - lead by Keri
# ['Keri', 'Lynn', 'Cristian']
# Group 3 - lead by Raekwon
# ['Raekwon', 'Vicky', 'Kainalu']
# Group 4 - lead by Rick
# ['Rick', 'Theodore', 'Marsha']
# Group 5 - lead by Marlon
# ['Marlon', 'Kobe', 'Kaitlin']
# Group 6 - lead by Vicky
# ['Vicky', 'Hope', 'Gene']
# Group 7 - lead by Tana
# ['Tana', 'Joy', 'Bernard']
# Group 8 - lead by Destiny
# ['Destiny', 'Ramona', 'Lena']
# Group 9 - lead by Colby
# ['Colby', 'Jaqueline', 'Agnes']
# Group 10 - lead by Dixie
# ['Dixie', 'Claire', 'Johnathon']
# Group 11 - lead by Makana
# ['Makana', 'Ezekiel', 'Ethan']
# Group 12 - lead by Loriann
# ['Loriann', 'Shaquille', 'Cyrus']
# Group 13 - lead by Dwayne
# ['Dwayne', 'Gabriela', 'Kailey']
# Group 14 - lead by Justice
# ['Justice', 'Samuel', 'Bryanna']
# Group 15 - lead by Janay
# ['Janay', 'Linda', 'Cristina']
# Group 16 - lead by Charlotte
# ['Charlotte', 'Sidney', 'Lori']
# Group 17 - lead by Sebastian
# ['Sebastian', 'Aiden', 'Teresa']
# Group 18 - lead by Brody
# ['Brody', 'Audra', 'Chase']
# Group 19 - lead by Kylie
# ['Kylie', 'Brandie', 'Irma']
# Group 20 - lead by Jefferson
# ['Jefferson', 'Kainoa', 'Ayden']
# Group 21 - lead by Branden
# ['Branden', 'David', 'Don']
# Group 22 - lead by Marcia
# ['Marcia', 'Tori', 'Frances']
# Group 23 - lead by Laci
# ['Laci', 'Sheryl', 'Kenzie']
# Group 24 - lead by Gina
# ['Gina', 'Kainalu', 'Guadalupe']
# Group 25 - lead by Vicky
# ['Vicky', 'Marco', 'Shelbi']
# Group 26 - lead by Mahina
# ['Mahina', 'Latonya', 'Mandy']
# Group 27 - lead by Stacie
# ['Stacie', 'Miracle', 'Raegan']
# Group 28 - lead by Caitlin
# ['Caitlin', 'Allie', 'Sylvia']
# Group 29 - lead by Jesus
# ['Jesus', 'Trevor', 'Francis']
# Group 30 - lead by Barbara
# ['Barbara', 'Leon', 'Kristopher']
# Group 31 - lead by Kelley
# ['Kelley', 'Bonnie', 'Bryanna']
# Group 32 - lead by Chanel
# ['Chanel', 'Sydney', 'Kendrick']
# Group 33 - lead by Tabatha
# ['Tabatha', 'Andres', 'Dexter']
# Group 34 - lead by Raegan
# ['Raegan', 'Gloria', 'Brianna']
# Group 35 - lead by Wesley
# ['Wesley', 'Chiquita', 'Marion']
# Group 36 - lead by Eugene
# ['Eugene', 'Trinity', 'Charlotte']
# Group 37 - lead by Serenity
# ['Serenity', 'Janiya', 'Kylie']
# Group 38 - lead by Henry
# ['Henry', 'Tracey', 'Nia']
# Group 39 - lead by Kaitlyn
# ['Kaitlyn', 'Jaylon', 'Cristina']
# Group 40 - lead by Ciara
# ['Ciara', 'Linda', 'Sherri']
# Group 41 - lead by Jimmy
# ['Jimmy', 'Tyler', 'Desiree']
# Group 42 - lead by Craig
# ['Craig', 'Austin', 'Carson']
# Group 43 - lead by Sierra
# ['Sierra', 'Marie', 'Chiquita']
# Group 44 - lead by Tabitha
# ['Tabitha', 'Tracey', 'Rosie']
# Group 45 - lead by Sonya
# ['Sonya', 'Orlando', 'Darrell']
# Group 46 - lead by Lani
# ['Lani', 'Lorenzo', 'Bethany']
# Group 47 - lead by Warren
# ['Warren', 'Deja', 'Kalani']
# Group 48 - lead by Betsy
# ['Betsy', 'Myra', 'Cheri']
# Group 49 - lead by Georgia
# ['Georgia', 'Mckay', 'Dawson']
# Group 50 - lead by Luis
# ['Luis', 'Danica', 'Alexa']
# Group 51 - lead by Maribel
# ['Maribel', 'Jamya', 'Sally']
# Group 52 - lead by Bryant
# ['Bryant', 'Arielle', 'Zayden']
# Group 53 - lead by Donald
# ['Donald', 'Meghan', 'Kay']
# Group 54 - lead by Kris
# ['Kris', 'Keoni', 'Reagan']
# Group 55 - lead by Sophia
# ['Sophia', 'Raul', 'Latasha']
# Group 56 - lead by Dana
# ['Dana', 'Brandy', 'Alex']
# Group 57 - lead by Jasmine
# ['Jasmine', 'Noelani', 'Edward']
# Group 58 - lead by Donnie
# ['Donnie', 'Nasir', 'Destiny']
# Group 59 - lead by Craig
# ['Craig', 'Misti', 'Tristan']
#
#
# Week 3
#
# Group 1 - lead by Brandie
# ['Brandie', 'Bonnie', 'Luis']
# Group 2 - lead by Kainalu
# ['Kainalu', 'Sherri', 'Dana']
# Group 3 - lead by Andres
# ['Andres', 'Marlon', 'Raegan']
# Group 4 - lead by Danica
# ['Danica', 'Theodore', 'Sydney']
# Group 5 - lead by Joy
# ['Joy', 'Trevor', 'Charlotte']
# Group 6 - lead by Kalani
# ['Kalani', 'Kainalu', 'Branden']
# Group 7 - lead by Zayden
# ['Zayden', 'Raegan', 'Donnie']
# Group 8 - lead by Bryanna
# ['Bryanna', 'Jasmine', 'Myron']
# Group 9 - lead by Cyrus
# ['Cyrus', 'Kendrick', 'Ramona']
# Group 10 - lead by Noelani
# ['Noelani', 'Hope', 'Kainoa']
# Group 11 - lead by Tracey
# ['Tracey', 'Kaitlyn', 'Kylie']
# Group 12 - lead by Reagan
# ['Reagan', 'Ciara', 'Misti']
# Group 13 - lead by Tori
# ['Tori', 'Kris', 'Tracey']
# Group 14 - lead by Marco
# ['Marco', 'Bernard', 'Georgia']
# Group 15 - lead by Don
# ['Don', 'Jaylon', 'Bryant']
# Group 16 - lead by Orlando
# ['Orlando', 'Arielle', 'Eugene']
# Group 17 - lead by Cheri
# ['Cheri', 'David', 'Bryanna']
# Group 18 - lead by Meghan
# ['Meghan', 'Jimmy', 'Loriann']
# Group 19 - lead by Rosie
# ['Rosie', 'Tabitha', 'Kailey']
# Group 20 - lead by Carson
# ['Carson', 'Makana', 'Marsha']
# Group 21 - lead by Kobe
# ['Kobe', 'Wesley', 'Tana']
# Group 22 - lead by Francis
# ['Francis', 'Austin', 'Irma']
# Group 23 - lead by Keoni
# ['Keoni', 'Johnathon', 'Lorenzo']
# Group 24 - lead by Sally
# ['Sally', 'Vicky', 'Gloria']
# Group 25 - lead by Janiya
# ['Janiya', 'Raekwon', 'Sylvia']
# Group 26 - lead by Kay
# ['Kay', 'Samuel', 'Tabatha']
# Group 27 - lead by Mckay
# ['Mckay', 'Kristopher', 'Miracle']
# Group 28 - lead by Alex
# ['Alex', 'Jefferson', 'Guadalupe']
# Group 29 - lead by Mandy
# ['Mandy', 'Mahina', 'Trinity']
# Group 30 - lead by Linda
# ['Linda', 'Chanel', 'Warren']
# Group 31 - lead by Darrell
# ['Darrell', 'Raul', 'Edward']
# Group 32 - lead by Shawna
# ['Shawna', 'Tyler', 'Serenity']
# Group 33 - lead by Brianna
# ['Brianna', 'Marcia', 'Ayden']
# Group 34 - lead by Sheryl
# ['Sheryl', 'Henry', 'Kaitlin']
# Group 35 - lead by Sidney
# ['Sidney', 'Leon', 'Allie']
# Group 36 - lead by Tristan
# ['Tristan', 'Chiquita', 'Janay']
# Group 37 - lead by Agnes
# ['Agnes', 'Barbara', 'Dixie']
# Group 38 - lead by Lena
# ['Lena', 'Gabriela', 'Colby']
# Group 39 - lead by Chase
# ['Chase', 'Linda', 'Sierra']
# Group 40 - lead by Kenzie
# ['Kenzie', 'Jamya', 'Vicky']
# Group 41 - lead by Cristina
# ['Cristina', 'Deja', 'Maribel']
# Group 42 - lead by Lynn
# ['Lynn', 'Destiny', 'Jaqueline']
# Group 43 - lead by Shelbi
# ['Shelbi', 'Jesus', 'Vicky']
# Group 44 - lead by Desiree
# ['Desiree', 'Craig', 'Dwayne']
# Group 45 - lead by Roderick
# ['Roderick', 'Craig', 'Latonya']
# Group 46 - lead by Aiden
# ['Aiden', 'Justice', 'Destiny']
# Group 47 - lead by Ethan
# ['Ethan', 'Gina', 'Sonya']
# Group 48 - lead by Nia
# ['Nia', 'Cristina', 'Frances']
# Group 49 - lead by Latasha
# ['Latasha', 'Shaquille', 'Marion']
# Group 50 - lead by Bethany
# ['Bethany', 'Laci', 'Nasir']
# Group 51 - lead by Kylie
# ['Kylie', 'Gene', 'Betsy']
# Group 52 - lead by Chiquita
# ['Chiquita', 'Brandy', 'Myra']
# Group 53 - lead by Teresa
# ['Teresa', 'Caitlin', 'Ezekiel']
# Group 54 - lead by Dawson
# ['Dawson', 'Donald', 'Kelley']
# Group 55 - lead by Dexter
# ['Dexter', 'Rick', 'Brody']
# Group 56 - lead by Charlotte
# ['Charlotte', 'Sebastian', 'Sophia']
# Group 57 - lead by Marie
# ['Marie', 'Alexa', 'Stacie']
# Group 58 - lead by Audra
# ['Audra', 'Lani', 'Claire']
# Group 59 - lead by Lori
# ['Lori', 'Cristian', 'Keri']
#
#
# Week 4
#
# Group 1 - lead by Misti
# ['Misti', 'Cyrus', 'Raegan']
# Group 2 - lead by Theodore
# ['Theodore', 'Edward', 'Teresa']
# Group 3 - lead by Colby
# ['Colby', 'Reagan', 'Johnathon']
# Group 4 - lead by Laci
# ['Laci', 'Barbara', 'Maribel']
# Group 5 - lead by Orlando
# ['Orlando', 'Sidney', 'Kobe']
# Group 6 - lead by Jaqueline
# ['Jaqueline', 'Kelley', 'Leon']
# Group 7 - lead by Tracey
# ['Tracey', 'Bryanna', 'Bryanna']
# Group 8 - lead by Dwayne
# ['Dwayne', 'Dawson', 'Kalani']
# Group 9 - lead by Dexter
# ['Dexter', 'Cristina', 'Ethan']
# Group 10 - lead by Lani
# ['Lani', 'Darrell', 'Jamya']
# Group 11 - lead by Caitlin
# ['Caitlin', 'Marlon', 'Arielle']
# Group 12 - lead by Francis
# ['Francis', 'Tana', 'Brianna']
# Group 13 - lead by Chase
# ['Chase', 'Kenzie', 'Mahina']
# Group 14 - lead by Serenity
# ['Serenity', 'Mandy', 'Rick']
# Group 15 - lead by Bonnie
# ['Bonnie', 'Latasha', 'Lori']
# Group 16 - lead by Guadalupe
# ['Guadalupe', 'Chiquita', 'Noelani']
# Group 17 - lead by Keoni
# ['Keoni', 'Bethany', 'Zayden']
# Group 18 - lead by Kailey
# ['Kailey', 'Marcia', 'Mckay']
# Group 19 - lead by Justice
# ['Justice', 'Myron', 'Kristopher']
# Group 20 - lead by Raegan
# ['Raegan', 'Nia', 'Myra']
# Group 21 - lead by Sally
# ['Sally', 'Marion', 'Linda']
# Group 22 - lead by Nasir
# ['Nasir', 'Desiree', 'David']
# Group 23 - lead by Ciara
# ['Ciara', 'Kainalu', 'Deja']
# Group 24 - lead by Tabitha
# ['Tabitha', 'Shawna', 'Destiny']
# Group 25 - lead by Jasmine
# ['Jasmine', 'Donald', 'Tyler']
# Group 26 - lead by Aiden
# ['Aiden', 'Bryant', 'Brody']
# Group 27 - lead by Cristina
# ['Cristina', 'Sonya', 'Kainoa']
# Group 28 - lead by Sherri
# ['Sherri', 'Sophia', 'Donnie']
# Group 29 - lead by Jefferson
# ['Jefferson', 'Vicky', 'Hope']
# Group 30 - lead by Charlotte
# ['Charlotte', 'Frances', 'Miracle']
# Group 31 - lead by Tristan
# ['Tristan', 'Alexa', 'Makana']
# Group 32 - lead by Branden
# ['Branden', 'Jesus', 'Kris']
# Group 33 - lead by Sebastian
# ['Sebastian', 'Kylie', 'Tori']
# Group 34 - lead by Allie
# ['Allie', 'Danica', 'Cristian']
# Group 35 - lead by Ramona
# ['Ramona', 'Samuel', 'Austin']
# Group 36 - lead by Don
# ['Don', 'Dana', 'Marsha']
# Group 37 - lead by Georgia
# ['Georgia', 'Gene', 'Craig']
# Group 38 - lead by Kaitlin
# ['Kaitlin', 'Janiya', 'Claire']
# Group 39 - lead by Stacie
# ['Stacie', 'Chiquita', 'Rosie']
# Group 40 - lead by Chanel
# ['Chanel', 'Destiny', 'Gabriela']
# Group 41 - lead by Carson
# ['Carson', 'Trevor', 'Linda']
# Group 42 - lead by Gloria
# ['Gloria', 'Marie', 'Ayden']
# Group 43 - lead by Roderick
# ['Roderick', 'Tracey', 'Jimmy']
# Group 44 - lead by Henry
# ['Henry', 'Kay', 'Alex']
# Group 45 - lead by Kainalu
# ['Kainalu', 'Marco', 'Joy']
# Group 46 - lead by Irma
# ['Irma', 'Dixie', 'Lena']
# Group 47 - lead by Lorenzo
# ['Lorenzo', 'Raekwon', 'Shelbi']
# Group 48 - lead by Ezekiel
# ['Ezekiel', 'Janay', 'Betsy']
# Group 49 - lead by Luis
# ['Luis', 'Keri', 'Craig']
# Group 50 - lead by Eugene
# ['Eugene', 'Sylvia', 'Trinity']
# Group 51 - lead by Meghan
# ['Meghan', 'Sydney', 'Jaylon']
# Group 52 - lead by Charlotte
# ['Charlotte', 'Wesley', 'Shaquille']
# Group 53 - lead by Raul
# ['Raul', 'Kylie', 'Vicky']
# Group 54 - lead by Warren
# ['Warren', 'Cheri', 'Gina']
# Group 55 - lead by Brandy
# ['Brandy', 'Sheryl', 'Andres']
# Group 56 - lead by Kendrick
# ['Kendrick', 'Kaitlyn', 'Bernard']
# Group 57 - lead by Audra
# ['Audra', 'Vicky', 'Agnes']
# Group 58 - lead by Loriann
# ['Loriann', 'Latonya', 'Tabatha']
# Group 59 - lead by Sierra
# ['Sierra', 'Brandie', 'Lynn']
#
#
# Week 5
#
# Group 1 - lead by Joy
# ['Joy', 'Cristian', 'Sherri']
# Group 2 - lead by Cyrus
# ['Cyrus', 'Guadalupe', 'Wesley']
# Group 3 - lead by Vicky
# ['Vicky', 'Shaquille', 'Dawson']
# Group 4 - lead by Arielle
# ['Arielle', 'Kendrick', 'Dwayne']
# Group 5 - lead by Cheri
# ['Cheri', 'Cristina', 'Kay']
# Group 6 - lead by Reagan
# ['Reagan', 'Theodore', 'Colby']
# Group 7 - lead by Kristopher
# ['Kristopher', 'Don', 'Chiquita']
# Group 8 - lead by Jesus
# ['Jesus', 'Kainalu', 'Jasmine']
# Group 9 - lead by Teresa
# ['Teresa', 'Destiny', 'Craig']
# Group 10 - lead by Bernard
# ['Bernard', 'Lani', 'Bonnie']
# Group 11 - lead by Andres
# ['Andres', 'Caitlin', 'Charlotte']
# Group 12 - lead by Noelani
# ['Noelani', 'Tana', 'Tracey']
# Group 13 - lead by Marlon
# ['Marlon', 'Dexter', 'Audra']
# Group 14 - lead by Linda
# ['Linda', 'Tori', 'Brody']
# Group 15 - lead by Makana
# ['Makana', 'Kainalu', 'Tyler']
# Group 16 - lead by Samuel
# ['Samuel', 'Stacie', 'Chase']
# Group 17 - lead by Barbara
# ['Barbara', 'Ethan', 'Betsy']
# Group 18 - lead by Marion
# ['Marion', 'Sally', 'Donnie']
# Group 19 - lead by Lena
# ['Lena', 'Allie', 'Chanel']
# Group 20 - lead by Miracle
# ['Miracle', 'Bethany', 'Tristan']
# Group 21 - lead by Trevor
# ['Trevor', 'Jaqueline', 'Ramona']
# Group 22 - lead by Vicky
# ['Vicky', 'Zayden', 'Destiny']
# Group 23 - lead by Darrell
# ['Darrell', 'Roderick', 'Raul']
# Group 24 - lead by Latasha
# ['Latasha', 'Irma', 'Tabitha']
# Group 25 - lead by Craig
# ['Craig', 'Agnes', 'Janay']
# Group 26 - lead by Sonya
# ['Sonya', 'Orlando', 'Gene']
# Group 27 - lead by Sydney
# ['Sydney', 'Bryanna', 'Gabriela']
# Group 28 - lead by Austin
# ['Austin', 'Shawna', 'Edward']
# Group 29 - lead by Marco
# ['Marco', 'Gina', 'Lori']
# Group 30 - lead by Hope
# ['Hope', 'Trinity', 'Myra']
# Group 31 - lead by Sophia
# ['Sophia', 'Georgia', 'Sierra']
# Group 32 - lead by Marsha
# ['Marsha', 'Frances', 'Kalani']
# Group 33 - lead by Latonya
# ['Latonya', 'Leon', 'Charlotte']
# Group 34 - lead by Brianna
# ['Brianna', 'Kaitlyn', 'Johnathon']
# Group 35 - lead by Tracey
# ['Tracey', 'Dana', 'Kelley']
# Group 36 - lead by Jaylon
# ['Jaylon', 'Raekwon', 'Henry']
# Group 37 - lead by Claire
# ['Claire', 'Raegan', 'Meghan']
# Group 38 - lead by Maribel
# ['Maribel', 'Vicky', 'Kaitlin']
# Group 39 - lead by Janiya
# ['Janiya', 'Sheryl', 'Aiden']
# Group 40 - lead by Jimmy
# ['Jimmy', 'Rick', 'Ayden']
# Group 41 - lead by Shelbi
# ['Shelbi', 'Danica', 'Linda']
# Group 42 - lead by Alex
# ['Alex', 'Warren', 'Jamya']
# Group 43 - lead by Mandy
# ['Mandy', 'Desiree', 'Chiquita']
# Group 44 - lead by Bryanna
# ['Bryanna', 'Loriann', 'Lorenzo']
# Group 45 - lead by Deja
# ['Deja', 'Misti', 'Branden']
# Group 46 - lead by Kylie
# ['Kylie', 'Keoni', 'Cristina']
# Group 47 - lead by Sidney
# ['Sidney', 'Nasir', 'Francis']
# Group 48 - lead by Donald
# ['Donald', 'Sebastian', 'Luis']
# Group 49 - lead by Dixie
# ['Dixie', 'Eugene', 'Justice']
# Group 50 - lead by Bryant
# ['Bryant', 'Alexa', 'Ciara']
# Group 51 - lead by Mahina
# ['Mahina', 'Carson', 'Marie']
# Group 52 - lead by Mckay
# ['Mckay', 'Myron', 'Lynn']
# Group 53 - lead by Keri
# ['Keri', 'Nia', 'Jefferson']
# Group 54 - lead by Kobe
# ['Kobe', 'Ezekiel', 'Laci']
# Group 55 - lead by Rosie
# ['Rosie', 'Kylie', 'Kris']
# Group 56 - lead by Marcia
# ['Marcia', 'Kailey', 'Gloria']
# Group 57 - lead by Brandie
# ['Brandie', 'David', 'Kainoa']
# Group 58 - lead by Tabatha
# ['Tabatha', 'Serenity', 'Sylvia']
# Group 59 - lead by Raegan
# ['Raegan', 'Kenzie', 'Brandy']
